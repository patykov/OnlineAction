# %%
import argparse
import pickle
import re

import torch

import sys
sys.path.insert(0, '..')
from models.baselines.nonlocal_net import resnet50, resnet101
# from models.convert_caffe2pytorch import convert_i3d_weights

# %%
charades50_file = '/data/OnlineActionRecognition/models/pre-trained/long-term-feature-banks/charades_r50_baseline_i3d_nl.pkl'
charades101_file = '/data/OnlineActionRecognition/models/pre-trained/long-term-feature-banks/charades_r101_baseline_i3d_nl.pkl'
ava50_file = '/data/OnlineActionRecognition/models/pre-trained/long-term-feature-banks/ava_r50_baseline_i3d_nl.pkl'
ava101_file = '/data/OnlineActionRecognition/models/pre-trained/long-term-feature-banks/ava_r101_baseline_i3d_nl.pkl'

# %%
data = pickle.load(open(charades50_file, 'rb'), encoding='latin')['blobs']
data = {k: v for k, v in data.items() if 'momentum' not in k}
sorted(data.keys())
# Out:
# ['conv1_w',
#  'lr',
#  'model_iter',
#  'nonlocal_conv3_1_bn_b',
#  'nonlocal_conv3_1_bn_s',
#  'nonlocal_conv3_1_g_b',
#  'nonlocal_conv3_1_g_w',
#  'nonlocal_conv3_1_out_b',
#  'nonlocal_conv3_1_out_w',
#  'nonlocal_conv3_1_phi_b',
#  'nonlocal_conv3_1_phi_w',
#  'nonlocal_conv3_1_theta_b',
#  'nonlocal_conv3_1_theta_w',
#  'nonlocal_conv3_3_bn_b',
#  'nonlocal_conv3_3_bn_s',
#  'nonlocal_conv3_3_g_b',
#  'nonlocal_conv3_3_g_w',
#  'nonlocal_conv3_3_out_b',
#  'nonlocal_conv3_3_out_w',
#  'nonlocal_conv3_3_phi_b',
#  'nonlocal_conv3_3_phi_w',
#  'nonlocal_conv3_3_theta_b',
#  'nonlocal_conv3_3_theta_w',
#  'nonlocal_conv4_1_bn_b',
#  'nonlocal_conv4_1_bn_s',
#  'nonlocal_conv4_1_g_b',
#  'nonlocal_conv4_1_g_w',
#  'nonlocal_conv4_1_out_b',
#  'nonlocal_conv4_1_out_w',
#  'nonlocal_conv4_1_phi_b',
#  'nonlocal_conv4_1_phi_w',
#  'nonlocal_conv4_1_theta_b',
#  'nonlocal_conv4_1_theta_w',
#  'nonlocal_conv4_3_bn_b',
#  'nonlocal_conv4_3_bn_s',
#  'nonlocal_conv4_3_g_b',
#  'nonlocal_conv4_3_g_w',
#  'nonlocal_conv4_3_out_b',
#  'nonlocal_conv4_3_out_w',
#  'nonlocal_conv4_3_phi_b',
#  'nonlocal_conv4_3_phi_w',
#  'nonlocal_conv4_3_theta_b',
#  'nonlocal_conv4_3_theta_w',
#  'nonlocal_conv4_5_bn_b',
#  'nonlocal_conv4_5_bn_s',
#  'nonlocal_conv4_5_g_b',
#  'nonlocal_conv4_5_g_w',
#  'nonlocal_conv4_5_out_b',
#  'nonlocal_conv4_5_out_w',
#  'nonlocal_conv4_5_phi_b',
#  'nonlocal_conv4_5_phi_w',
#  'nonlocal_conv4_5_theta_b',
#  'nonlocal_conv4_5_theta_w',
#  'pred_b',
#  'pred_w',
#  'res2_0_branch1_bn_b',
#  'res2_0_branch1_bn_s',
#  'res2_0_branch1_w',
#  'res2_0_branch2a_bn_b',
#  'res2_0_branch2a_bn_s',
#  'res2_0_branch2a_w',
#  'res2_0_branch2b_bn_b',
#  'res2_0_branch2b_bn_s',
#  'res2_0_branch2b_w',
#  'res2_0_branch2c_bn_b',
#  'res2_0_branch2c_bn_s',
#  'res2_0_branch2c_w',
#  'res2_1_branch2a_bn_b',
#  'res2_1_branch2a_bn_s',
#  'res2_1_branch2a_w',
#  'res2_1_branch2b_bn_b',
#  'res2_1_branch2b_bn_s',
#  'res2_1_branch2b_w',
#  'res2_1_branch2c_bn_b',
#  'res2_1_branch2c_bn_s',
#  'res2_1_branch2c_w',
#  'res2_2_branch2a_bn_b',
#  'res2_2_branch2a_bn_s',
#  'res2_2_branch2a_w',
#  'res2_2_branch2b_bn_b',
#  'res2_2_branch2b_bn_s',
#  'res2_2_branch2b_w',
#  'res2_2_branch2c_bn_b',
#  'res2_2_branch2c_bn_s',
#  'res2_2_branch2c_w',
#  'res3_0_branch1_bn_b',
#  'res3_0_branch1_bn_s',
#  'res3_0_branch1_w',
#  'res3_0_branch2a_bn_b',
#  'res3_0_branch2a_bn_s',
#  'res3_0_branch2a_w',
#  'res3_0_branch2b_bn_b',
#  'res3_0_branch2b_bn_s',
#  'res3_0_branch2b_w',
#  'res3_0_branch2c_bn_b',
#  'res3_0_branch2c_bn_s',
#  'res3_0_branch2c_w',
#  'res3_1_branch2a_bn_b',
#  'res3_1_branch2a_bn_s',
#  'res3_1_branch2a_w',
#  'res3_1_branch2b_bn_b',
#  'res3_1_branch2b_bn_s',
#  'res3_1_branch2b_w',
#  'res3_1_branch2c_bn_b',
#  'res3_1_branch2c_bn_s',
#  'res3_1_branch2c_w',
#  'res3_2_branch2a_bn_b',
#  'res3_2_branch2a_bn_s',
#  'res3_2_branch2a_w',
#  'res3_2_branch2b_bn_b',
#  'res3_2_branch2b_bn_s',
#  'res3_2_branch2b_w',
#  'res3_2_branch2c_bn_b',
#  'res3_2_branch2c_bn_s',
#  'res3_2_branch2c_w',
#  'res3_3_branch2a_bn_b',
#  'res3_3_branch2a_bn_s',
#  'res3_3_branch2a_w',
#  'res3_3_branch2b_bn_b',
#  'res3_3_branch2b_bn_s',
#  'res3_3_branch2b_w',
#  'res3_3_branch2c_bn_b',
#  'res3_3_branch2c_bn_s',
#  'res3_3_branch2c_w',
#  'res4_0_branch1_bn_b',
#  'res4_0_branch1_bn_s',
#  'res4_0_branch1_w',
#  'res4_0_branch2a_bn_b',
#  'res4_0_branch2a_bn_s',
#  'res4_0_branch2a_w',
#  'res4_0_branch2b_bn_b',
#  'res4_0_branch2b_bn_s',
#  'res4_0_branch2b_w',
#  'res4_0_branch2c_bn_b',
#  'res4_0_branch2c_bn_s',
#  'res4_0_branch2c_w',
#  'res4_1_branch2a_bn_b',
#  'res4_1_branch2a_bn_s',
#  'res4_1_branch2a_w',
#  'res4_1_branch2b_bn_b',
#  'res4_1_branch2b_bn_s',
#  'res4_1_branch2b_w',
#  'res4_1_branch2c_bn_b',
#  'res4_1_branch2c_bn_s',
#  'res4_1_branch2c_w',
#  'res4_2_branch2a_bn_b',
#  'res4_2_branch2a_bn_s',
#  'res4_2_branch2a_w',
#  'res4_2_branch2b_bn_b',
#  'res4_2_branch2b_bn_s',
#  'res4_2_branch2b_w',
#  'res4_2_branch2c_bn_b',
#  'res4_2_branch2c_bn_s',
#  'res4_2_branch2c_w',
#  'res4_3_branch2a_bn_b',
#  'res4_3_branch2a_bn_s',
#  'res4_3_branch2a_w',
#  'res4_3_branch2b_bn_b',
#  'res4_3_branch2b_bn_s',
#  'res4_3_branch2b_w',
#  'res4_3_branch2c_bn_b',
#  'res4_3_branch2c_bn_s',
#  'res4_3_branch2c_w',
#  'res4_4_branch2a_bn_b',
#  'res4_4_branch2a_bn_s',
#  'res4_4_branch2a_w',
#  'res4_4_branch2b_bn_b',
#  'res4_4_branch2b_bn_s',
#  'res4_4_branch2b_w',
#  'res4_4_branch2c_bn_b',
#  'res4_4_branch2c_bn_s',
#  'res4_4_branch2c_w',
#  'res4_5_branch2a_bn_b',
#  'res4_5_branch2a_bn_s',
#  'res4_5_branch2a_w',
#  'res4_5_branch2b_bn_b',
#  'res4_5_branch2b_bn_s',
#  'res4_5_branch2b_w',
#  'res4_5_branch2c_bn_b',
#  'res4_5_branch2c_bn_s',
#  'res4_5_branch2c_w',
#  'res5_0_branch1_bn_b',
#  'res5_0_branch1_bn_s',
#  'res5_0_branch1_w',
#  'res5_0_branch2a_bn_b',
#  'res5_0_branch2a_bn_s',
#  'res5_0_branch2a_w',
#  'res5_0_branch2b_bn_b',
#  'res5_0_branch2b_bn_s',
#  'res5_0_branch2b_w',
#  'res5_0_branch2c_bn_b',
#  'res5_0_branch2c_bn_s',
#  'res5_0_branch2c_w',
#  'res5_1_branch2a_bn_b',
#  'res5_1_branch2a_bn_s',
#  'res5_1_branch2a_w',
#  'res5_1_branch2b_bn_b',
#  'res5_1_branch2b_bn_s',
#  'res5_1_branch2b_w',
#  'res5_1_branch2c_bn_b',
#  'res5_1_branch2c_bn_s',
#  'res5_1_branch2c_w',
#  'res5_2_branch2a_bn_b',
#  'res5_2_branch2a_bn_s',
#  'res5_2_branch2a_w',
#  'res5_2_branch2b_bn_b',
#  'res5_2_branch2b_bn_s',
#  'res5_2_branch2b_w',
#  'res5_2_branch2c_bn_b',
#  'res5_2_branch2c_bn_s',
#  'res5_2_branch2c_w',
#  'res_conv1_bn_b',
#  'res_conv1_bn_s']

# %%
def convert_i3d_weights(weigths_file_path, new_model, save_model=False, new_model_name=None):
    """Expanded from https://github.com/Tushar-N/pytorch-resnet3d
    Convert pre-trained weights of I3DResnet from caffe2 to Pytorch.
    """

    data = pickle.load(open(weigths_file_path, 'rb'), encoding='latin')['blobs']
    data = {k: v for k, v in data.items() if 'momentum' not in k}

    downsample_pat = re.compile('res(.)_(.)_branch1_.*')
    conv_pat = re.compile('res(.)_(.)_branch2(.)_.*')
    nonlocal_pat = re.compile('nonlocal_conv(.)_(.)_*')
    m2num = dict(zip('abc', [1, 2, 3]))
    suffix_dict = {
        'b': 'bias', 'w': 'weight', 's': 'weight'}
    nonlocal_dict = {'out': 'W.0', 'bn': 'W.1', 'phi': 'phi.1', 'g': 'g.1', 'theta': 'theta'}

    key_map = {'conv1.weight': 'conv1_w',
               'bn1.weight': 'res_conv1_bn_s',
               'bn1.bias': 'res_conv1_bn_b',
               'fc.weight': 'pred_w',
               'fc.bias': 'pred_b'}

    for key in data:
        conv_match = conv_pat.match(key)
        if conv_match:
            layer, block, module = conv_match.groups()
            layer, block, module = int(layer), int(block), m2num[module]
            name = 'bn' if 'bn_' in key else 'conv'
            suffix = suffix_dict[key.split('_')[-1]]
            new_key = 'layer%d.%d.%s%d.%s' % (layer-1, block, name, module, suffix)
            key_map[new_key] = key

        ds_match = downsample_pat.match(key)
        if ds_match:
            layer, block = ds_match.groups()
            layer, block = int(layer), int(block)
            module = 0 if key[-1] == 'w' else 1
            name = 'downsample'
            suffix = suffix_dict[key.split('_')[-1]]
            new_key = 'layer%d.%d.%s.%d.%s' % (layer-1, block, name, module, suffix)
            key_map[new_key] = key

        nl_match = nonlocal_pat.match(key)
        if nl_match:
            layer, block = nl_match.groups()
            layer, block = int(layer), int(block)
            nl_op = nonlocal_dict[key.split('_')[-2]]
            suffix = suffix_dict[key.split('_')[-1]]
            name = 'nonlocal_block'
            new_key = 'layer%d.%d.%s.%s.%s' % (layer-1, block, name, nl_op, suffix)
            key_map[new_key] = key

    state_dict = new_model.state_dict()

    new_state_dict = {
        key: torch.from_numpy(data[key_map[key]]) for key in state_dict if key in key_map}

    # Check if weight dimensions match
    for key in state_dict:

        if key not in key_map:
            continue

        data_v, pth_v = data[key_map[key]], state_dict[key]
        assert str(tuple(data_v.shape)) == str(tuple(pth_v.shape)), (
            'Size Mismatch {} != {} in {}').format(data_v.shape, pth_v.shape, key)
        print('{:24s} --> {:40s} | {:21s}'.format(key_map[key], key, str(tuple(data_v.shape))))

    if save_model:
        # Saving new model weights
        torch.save(new_state_dict, '{}.pth'.format(new_model_name))

    return new_model

# %%
blank_resnet50_i3d = resnet50(non_local=True, frame_num=32, num_classes=157)
blank_resnet101_i3d = resnet101(non_local=True, frame_num=32, num_classes=157)
ava_blank_resnet50_i3d = resnet50(non_local=True, frame_num=32, num_classes=80)
ava_blank_resnet101_i3d = resnet101(non_local=True, frame_num=32, num_classes=80)

# %%
charades50_i3dnl = convert_i3d_weights(charades50_file, blank_resnet50_i3d, save_model=True,
                                     new_model_name='/data/OnlineActionRecognition/models/pre-trained/'
                                     'long-term-feature-banks/charades_r50_i3d_nl_32x2')
# Out:
# conv1_w                  --> conv1.weight                             | (64, 3, 5, 7, 7)
# res_conv1_bn_s           --> bn1.weight                               | (64,)
# res_conv1_bn_b           --> bn1.bias                                 | (64,)
# res2_0_branch2a_w        --> layer1.0.conv1.weight                    | (64, 64, 3, 1, 1)
# res2_0_branch2a_bn_s     --> layer1.0.bn1.weight                      | (64,)
# res2_0_branch2a_bn_b     --> layer1.0.bn1.bias                        | (64,)
# res2_0_branch2b_w        --> layer1.0.conv2.weight                    | (64, 64, 1, 3, 3)
# res2_0_branch2b_bn_s     --> layer1.0.bn2.weight                      | (64,)
# res2_0_branch2b_bn_b     --> layer1.0.bn2.bias                        | (64,)
# res2_0_branch2c_w        --> layer1.0.conv3.weight                    | (256, 64, 1, 1, 1)
# res2_0_branch2c_bn_s     --> layer1.0.bn3.weight                      | (256,)
# res2_0_branch2c_bn_b     --> layer1.0.bn3.bias                        | (256,)
# res2_0_branch1_w         --> layer1.0.downsample.0.weight             | (256, 64, 1, 1, 1)
# res2_0_branch1_bn_s      --> layer1.0.downsample.1.weight             | (256,)
# res2_0_branch1_bn_b      --> layer1.0.downsample.1.bias               | (256,)
# res2_1_branch2a_w        --> layer1.1.conv1.weight                    | (64, 256, 3, 1, 1)
# res2_1_branch2a_bn_s     --> layer1.1.bn1.weight                      | (64,)
# res2_1_branch2a_bn_b     --> layer1.1.bn1.bias                        | (64,)
# res2_1_branch2b_w        --> layer1.1.conv2.weight                    | (64, 64, 1, 3, 3)
# res2_1_branch2b_bn_s     --> layer1.1.bn2.weight                      | (64,)
# res2_1_branch2b_bn_b     --> layer1.1.bn2.bias                        | (64,)
# res2_1_branch2c_w        --> layer1.1.conv3.weight                    | (256, 64, 1, 1, 1)
# res2_1_branch2c_bn_s     --> layer1.1.bn3.weight                      | (256,)
# res2_1_branch2c_bn_b     --> layer1.1.bn3.bias                        | (256,)
# res2_2_branch2a_w        --> layer1.2.conv1.weight                    | (64, 256, 3, 1, 1)
# res2_2_branch2a_bn_s     --> layer1.2.bn1.weight                      | (64,)
# res2_2_branch2a_bn_b     --> layer1.2.bn1.bias                        | (64,)
# res2_2_branch2b_w        --> layer1.2.conv2.weight                    | (64, 64, 1, 3, 3)
# res2_2_branch2b_bn_s     --> layer1.2.bn2.weight                      | (64,)
# res2_2_branch2b_bn_b     --> layer1.2.bn2.bias                        | (64,)
# res2_2_branch2c_w        --> layer1.2.conv3.weight                    | (256, 64, 1, 1, 1)
# res2_2_branch2c_bn_s     --> layer1.2.bn3.weight                      | (256,)
# res2_2_branch2c_bn_b     --> layer1.2.bn3.bias                        | (256,)
# res3_0_branch2a_w        --> layer2.0.conv1.weight                    | (128, 256, 3, 1, 1)
# res3_0_branch2a_bn_s     --> layer2.0.bn1.weight                      | (128,)
# res3_0_branch2a_bn_b     --> layer2.0.bn1.bias                        | (128,)
# res3_0_branch2b_w        --> layer2.0.conv2.weight                    | (128, 128, 1, 3, 3)
# res3_0_branch2b_bn_s     --> layer2.0.bn2.weight                      | (128,)
# res3_0_branch2b_bn_b     --> layer2.0.bn2.bias                        | (128,)
# res3_0_branch2c_w        --> layer2.0.conv3.weight                    | (512, 128, 1, 1, 1)
# res3_0_branch2c_bn_s     --> layer2.0.bn3.weight                      | (512,)
# res3_0_branch2c_bn_b     --> layer2.0.bn3.bias                        | (512,)
# res3_0_branch1_w         --> layer2.0.downsample.0.weight             | (512, 256, 1, 1, 1)
# res3_0_branch1_bn_s      --> layer2.0.downsample.1.weight             | (512,)
# res3_0_branch1_bn_b      --> layer2.0.downsample.1.bias               | (512,)
# res3_1_branch2a_w        --> layer2.1.conv1.weight                    | (128, 512, 1, 1, 1)
# res3_1_branch2a_bn_s     --> layer2.1.bn1.weight                      | (128,)
# res3_1_branch2a_bn_b     --> layer2.1.bn1.bias                        | (128,)
# res3_1_branch2b_w        --> layer2.1.conv2.weight                    | (128, 128, 1, 3, 3)
# res3_1_branch2b_bn_s     --> layer2.1.bn2.weight                      | (128,)
# res3_1_branch2b_bn_b     --> layer2.1.bn2.bias                        | (128,)
# res3_1_branch2c_w        --> layer2.1.conv3.weight                    | (512, 128, 1, 1, 1)
# res3_1_branch2c_bn_s     --> layer2.1.bn3.weight                      | (512,)
# res3_1_branch2c_bn_b     --> layer2.1.bn3.bias                        | (512,)
# nonlocal_conv3_1_g_w     --> layer2.1.nonlocal_block.g.1.weight       | (256, 512, 1, 1, 1)
# nonlocal_conv3_1_g_b     --> layer2.1.nonlocal_block.g.1.bias         | (256,)
# nonlocal_conv3_1_out_w   --> layer2.1.nonlocal_block.W.0.weight       | (512, 256, 1, 1, 1)
# nonlocal_conv3_1_out_b   --> layer2.1.nonlocal_block.W.0.bias         | (512,)
# nonlocal_conv3_1_bn_s    --> layer2.1.nonlocal_block.W.1.weight       | (512,)
# nonlocal_conv3_1_bn_b    --> layer2.1.nonlocal_block.W.1.bias         | (512,)
# nonlocal_conv3_1_theta_w --> layer2.1.nonlocal_block.theta.weight     | (256, 512, 1, 1, 1)
# nonlocal_conv3_1_theta_b --> layer2.1.nonlocal_block.theta.bias       | (256,)
# nonlocal_conv3_1_phi_w   --> layer2.1.nonlocal_block.phi.1.weight     | (256, 512, 1, 1, 1)
# nonlocal_conv3_1_phi_b   --> layer2.1.nonlocal_block.phi.1.bias       | (256,)
# res3_2_branch2a_w        --> layer2.2.conv1.weight                    | (128, 512, 3, 1, 1)
# res3_2_branch2a_bn_s     --> layer2.2.bn1.weight                      | (128,)
# res3_2_branch2a_bn_b     --> layer2.2.bn1.bias                        | (128,)
# res3_2_branch2b_w        --> layer2.2.conv2.weight                    | (128, 128, 1, 3, 3)
# res3_2_branch2b_bn_s     --> layer2.2.bn2.weight                      | (128,)
# res3_2_branch2b_bn_b     --> layer2.2.bn2.bias                        | (128,)
# res3_2_branch2c_w        --> layer2.2.conv3.weight                    | (512, 128, 1, 1, 1)
# res3_2_branch2c_bn_s     --> layer2.2.bn3.weight                      | (512,)
# res3_2_branch2c_bn_b     --> layer2.2.bn3.bias                        | (512,)
# res3_3_branch2a_w        --> layer2.3.conv1.weight                    | (128, 512, 1, 1, 1)
# res3_3_branch2a_bn_s     --> layer2.3.bn1.weight                      | (128,)
# res3_3_branch2a_bn_b     --> layer2.3.bn1.bias                        | (128,)
# res3_3_branch2b_w        --> layer2.3.conv2.weight                    | (128, 128, 1, 3, 3)
# res3_3_branch2b_bn_s     --> layer2.3.bn2.weight                      | (128,)
# res3_3_branch2b_bn_b     --> layer2.3.bn2.bias                        | (128,)
# res3_3_branch2c_w        --> layer2.3.conv3.weight                    | (512, 128, 1, 1, 1)
# res3_3_branch2c_bn_s     --> layer2.3.bn3.weight                      | (512,)
# res3_3_branch2c_bn_b     --> layer2.3.bn3.bias                        | (512,)
# nonlocal_conv3_3_g_w     --> layer2.3.nonlocal_block.g.1.weight       | (256, 512, 1, 1, 1)
# nonlocal_conv3_3_g_b     --> layer2.3.nonlocal_block.g.1.bias         | (256,)
# nonlocal_conv3_3_out_w   --> layer2.3.nonlocal_block.W.0.weight       | (512, 256, 1, 1, 1)
# nonlocal_conv3_3_out_b   --> layer2.3.nonlocal_block.W.0.bias         | (512,)
# nonlocal_conv3_3_bn_s    --> layer2.3.nonlocal_block.W.1.weight       | (512,)
# nonlocal_conv3_3_bn_b    --> layer2.3.nonlocal_block.W.1.bias         | (512,)
# nonlocal_conv3_3_theta_w --> layer2.3.nonlocal_block.theta.weight     | (256, 512, 1, 1, 1)
# nonlocal_conv3_3_theta_b --> layer2.3.nonlocal_block.theta.bias       | (256,)
# nonlocal_conv3_3_phi_w   --> layer2.3.nonlocal_block.phi.1.weight     | (256, 512, 1, 1, 1)
# nonlocal_conv3_3_phi_b   --> layer2.3.nonlocal_block.phi.1.bias       | (256,)
# res4_0_branch2a_w        --> layer3.0.conv1.weight                    | (256, 512, 3, 1, 1)
# res4_0_branch2a_bn_s     --> layer3.0.bn1.weight                      | (256,)
# res4_0_branch2a_bn_b     --> layer3.0.bn1.bias                        | (256,)
# res4_0_branch2b_w        --> layer3.0.conv2.weight                    | (256, 256, 1, 3, 3)
# res4_0_branch2b_bn_s     --> layer3.0.bn2.weight                      | (256,)
# res4_0_branch2b_bn_b     --> layer3.0.bn2.bias                        | (256,)
# res4_0_branch2c_w        --> layer3.0.conv3.weight                    | (1024, 256, 1, 1, 1)
# res4_0_branch2c_bn_s     --> layer3.0.bn3.weight                      | (1024,)
# res4_0_branch2c_bn_b     --> layer3.0.bn3.bias                        | (1024,)
# res4_0_branch1_w         --> layer3.0.downsample.0.weight             | (1024, 512, 1, 1, 1)
# res4_0_branch1_bn_s      --> layer3.0.downsample.1.weight             | (1024,)
# res4_0_branch1_bn_b      --> layer3.0.downsample.1.bias               | (1024,)
# res4_1_branch2a_w        --> layer3.1.conv1.weight                    | (256, 1024, 1, 1, 1)
# res4_1_branch2a_bn_s     --> layer3.1.bn1.weight                      | (256,)
# res4_1_branch2a_bn_b     --> layer3.1.bn1.bias                        | (256,)
# res4_1_branch2b_w        --> layer3.1.conv2.weight                    | (256, 256, 1, 3, 3)
# res4_1_branch2b_bn_s     --> layer3.1.bn2.weight                      | (256,)
# res4_1_branch2b_bn_b     --> layer3.1.bn2.bias                        | (256,)
# res4_1_branch2c_w        --> layer3.1.conv3.weight                    | (1024, 256, 1, 1, 1)
# res4_1_branch2c_bn_s     --> layer3.1.bn3.weight                      | (1024,)
# res4_1_branch2c_bn_b     --> layer3.1.bn3.bias                        | (1024,)
# nonlocal_conv4_1_g_w     --> layer3.1.nonlocal_block.g.1.weight       | (512, 1024, 1, 1, 1)
# nonlocal_conv4_1_g_b     --> layer3.1.nonlocal_block.g.1.bias         | (512,)
# nonlocal_conv4_1_out_w   --> layer3.1.nonlocal_block.W.0.weight       | (1024, 512, 1, 1, 1)
# nonlocal_conv4_1_out_b   --> layer3.1.nonlocal_block.W.0.bias         | (1024,)
# nonlocal_conv4_1_bn_s    --> layer3.1.nonlocal_block.W.1.weight       | (1024,)
# nonlocal_conv4_1_bn_b    --> layer3.1.nonlocal_block.W.1.bias         | (1024,)
# nonlocal_conv4_1_theta_w --> layer3.1.nonlocal_block.theta.weight     | (512, 1024, 1, 1, 1)
# nonlocal_conv4_1_theta_b --> layer3.1.nonlocal_block.theta.bias       | (512,)
# nonlocal_conv4_1_phi_w   --> layer3.1.nonlocal_block.phi.1.weight     | (512, 1024, 1, 1, 1)
# nonlocal_conv4_1_phi_b   --> layer3.1.nonlocal_block.phi.1.bias       | (512,)
# res4_2_branch2a_w        --> layer3.2.conv1.weight                    | (256, 1024, 3, 1, 1)
# res4_2_branch2a_bn_s     --> layer3.2.bn1.weight                      | (256,)
# res4_2_branch2a_bn_b     --> layer3.2.bn1.bias                        | (256,)
# res4_2_branch2b_w        --> layer3.2.conv2.weight                    | (256, 256, 1, 3, 3)
# res4_2_branch2b_bn_s     --> layer3.2.bn2.weight                      | (256,)
# res4_2_branch2b_bn_b     --> layer3.2.bn2.bias                        | (256,)
# res4_2_branch2c_w        --> layer3.2.conv3.weight                    | (1024, 256, 1, 1, 1)
# res4_2_branch2c_bn_s     --> layer3.2.bn3.weight                      | (1024,)
# res4_2_branch2c_bn_b     --> layer3.2.bn3.bias                        | (1024,)
# res4_3_branch2a_w        --> layer3.3.conv1.weight                    | (256, 1024, 1, 1, 1)
# res4_3_branch2a_bn_s     --> layer3.3.bn1.weight                      | (256,)
# res4_3_branch2a_bn_b     --> layer3.3.bn1.bias                        | (256,)
# res4_3_branch2b_w        --> layer3.3.conv2.weight                    | (256, 256, 1, 3, 3)
# res4_3_branch2b_bn_s     --> layer3.3.bn2.weight                      | (256,)
# res4_3_branch2b_bn_b     --> layer3.3.bn2.bias                        | (256,)
# res4_3_branch2c_w        --> layer3.3.conv3.weight                    | (1024, 256, 1, 1, 1)
# res4_3_branch2c_bn_s     --> layer3.3.bn3.weight                      | (1024,)
# res4_3_branch2c_bn_b     --> layer3.3.bn3.bias                        | (1024,)
# nonlocal_conv4_3_g_w     --> layer3.3.nonlocal_block.g.1.weight       | (512, 1024, 1, 1, 1)
# nonlocal_conv4_3_g_b     --> layer3.3.nonlocal_block.g.1.bias         | (512,)
# nonlocal_conv4_3_out_w   --> layer3.3.nonlocal_block.W.0.weight       | (1024, 512, 1, 1, 1)
# nonlocal_conv4_3_out_b   --> layer3.3.nonlocal_block.W.0.bias         | (1024,)
# nonlocal_conv4_3_bn_s    --> layer3.3.nonlocal_block.W.1.weight       | (1024,)
# nonlocal_conv4_3_bn_b    --> layer3.3.nonlocal_block.W.1.bias         | (1024,)
# nonlocal_conv4_3_theta_w --> layer3.3.nonlocal_block.theta.weight     | (512, 1024, 1, 1, 1)
# nonlocal_conv4_3_theta_b --> layer3.3.nonlocal_block.theta.bias       | (512,)
# nonlocal_conv4_3_phi_w   --> layer3.3.nonlocal_block.phi.1.weight     | (512, 1024, 1, 1, 1)
# nonlocal_conv4_3_phi_b   --> layer3.3.nonlocal_block.phi.1.bias       | (512,)
# res4_4_branch2a_w        --> layer3.4.conv1.weight                    | (256, 1024, 3, 1, 1)
# res4_4_branch2a_bn_s     --> layer3.4.bn1.weight                      | (256,)
# res4_4_branch2a_bn_b     --> layer3.4.bn1.bias                        | (256,)
# res4_4_branch2b_w        --> layer3.4.conv2.weight                    | (256, 256, 1, 3, 3)
# res4_4_branch2b_bn_s     --> layer3.4.bn2.weight                      | (256,)
# res4_4_branch2b_bn_b     --> layer3.4.bn2.bias                        | (256,)
# res4_4_branch2c_w        --> layer3.4.conv3.weight                    | (1024, 256, 1, 1, 1)
# res4_4_branch2c_bn_s     --> layer3.4.bn3.weight                      | (1024,)
# res4_4_branch2c_bn_b     --> layer3.4.bn3.bias                        | (1024,)
# res4_5_branch2a_w        --> layer3.5.conv1.weight                    | (256, 1024, 1, 1, 1)
# res4_5_branch2a_bn_s     --> layer3.5.bn1.weight                      | (256,)
# res4_5_branch2a_bn_b     --> layer3.5.bn1.bias                        | (256,)
# res4_5_branch2b_w        --> layer3.5.conv2.weight                    | (256, 256, 1, 3, 3)
# res4_5_branch2b_bn_s     --> layer3.5.bn2.weight                      | (256,)
# res4_5_branch2b_bn_b     --> layer3.5.bn2.bias                        | (256,)
# res4_5_branch2c_w        --> layer3.5.conv3.weight                    | (1024, 256, 1, 1, 1)
# res4_5_branch2c_bn_s     --> layer3.5.bn3.weight                      | (1024,)
# res4_5_branch2c_bn_b     --> layer3.5.bn3.bias                        | (1024,)
# nonlocal_conv4_5_g_w     --> layer3.5.nonlocal_block.g.1.weight       | (512, 1024, 1, 1, 1)
# nonlocal_conv4_5_g_b     --> layer3.5.nonlocal_block.g.1.bias         | (512,)
# nonlocal_conv4_5_out_w   --> layer3.5.nonlocal_block.W.0.weight       | (1024, 512, 1, 1, 1)
# nonlocal_conv4_5_out_b   --> layer3.5.nonlocal_block.W.0.bias         | (1024,)
# nonlocal_conv4_5_bn_s    --> layer3.5.nonlocal_block.W.1.weight       | (1024,)
# nonlocal_conv4_5_bn_b    --> layer3.5.nonlocal_block.W.1.bias         | (1024,)
# nonlocal_conv4_5_theta_w --> layer3.5.nonlocal_block.theta.weight     | (512, 1024, 1, 1, 1)
# nonlocal_conv4_5_theta_b --> layer3.5.nonlocal_block.theta.bias       | (512,)
# nonlocal_conv4_5_phi_w   --> layer3.5.nonlocal_block.phi.1.weight     | (512, 1024, 1, 1, 1)
# nonlocal_conv4_5_phi_b   --> layer3.5.nonlocal_block.phi.1.bias       | (512,)
# res5_0_branch2a_w        --> layer4.0.conv1.weight                    | (512, 1024, 1, 1, 1)
# res5_0_branch2a_bn_s     --> layer4.0.bn1.weight                      | (512,)
# res5_0_branch2a_bn_b     --> layer4.0.bn1.bias                        | (512,)
# res5_0_branch2b_w        --> layer4.0.conv2.weight                    | (512, 512, 1, 3, 3)
# res5_0_branch2b_bn_s     --> layer4.0.bn2.weight                      | (512,)
# res5_0_branch2b_bn_b     --> layer4.0.bn2.bias                        | (512,)
# res5_0_branch2c_w        --> layer4.0.conv3.weight                    | (2048, 512, 1, 1, 1)
# res5_0_branch2c_bn_s     --> layer4.0.bn3.weight                      | (2048,)
# res5_0_branch2c_bn_b     --> layer4.0.bn3.bias                        | (2048,)
# res5_0_branch1_w         --> layer4.0.downsample.0.weight             | (2048, 1024, 1, 1, 1)
# res5_0_branch1_bn_s      --> layer4.0.downsample.1.weight             | (2048,)
# res5_0_branch1_bn_b      --> layer4.0.downsample.1.bias               | (2048,)
# res5_1_branch2a_w        --> layer4.1.conv1.weight                    | (512, 2048, 3, 1, 1)
# res5_1_branch2a_bn_s     --> layer4.1.bn1.weight                      | (512,)
# res5_1_branch2a_bn_b     --> layer4.1.bn1.bias                        | (512,)
# res5_1_branch2b_w        --> layer4.1.conv2.weight                    | (512, 512, 1, 3, 3)
# res5_1_branch2b_bn_s     --> layer4.1.bn2.weight                      | (512,)
# res5_1_branch2b_bn_b     --> layer4.1.bn2.bias                        | (512,)
# res5_1_branch2c_w        --> layer4.1.conv3.weight                    | (2048, 512, 1, 1, 1)
# res5_1_branch2c_bn_s     --> layer4.1.bn3.weight                      | (2048,)
# res5_1_branch2c_bn_b     --> layer4.1.bn3.bias                        | (2048,)
# res5_2_branch2a_w        --> layer4.2.conv1.weight                    | (512, 2048, 1, 1, 1)
# res5_2_branch2a_bn_s     --> layer4.2.bn1.weight                      | (512,)
# res5_2_branch2a_bn_b     --> layer4.2.bn1.bias                        | (512,)
# res5_2_branch2b_w        --> layer4.2.conv2.weight                    | (512, 512, 1, 3, 3)
# res5_2_branch2b_bn_s     --> layer4.2.bn2.weight                      | (512,)
# res5_2_branch2b_bn_b     --> layer4.2.bn2.bias                        | (512,)
# res5_2_branch2c_w        --> layer4.2.conv3.weight                    | (2048, 512, 1, 1, 1)
# res5_2_branch2c_bn_s     --> layer4.2.bn3.weight                      | (2048,)
# res5_2_branch2c_bn_b     --> layer4.2.bn3.bias                        | (2048,)
# pred_w                   --> fc.weight                                | (157, 2048)
# pred_b                   --> fc.bias                                  | (157,)

# %%
charades101_i3dnl = convert_i3d_weights(charades101_file, blank_resnet101_i3d, save_model=True,
                                        new_model_name='/data/OnlineActionRecognition/models/pre-trained/'
                                        'long-term-feature-banks/charades_r101_i3d_nl_32x2')
# Out:
# conv1_w                  --> conv1.weight                             | (64, 3, 5, 7, 7)
# res_conv1_bn_s           --> bn1.weight                               | (64,)
# res_conv1_bn_b           --> bn1.bias                                 | (64,)
# res2_0_branch2a_w        --> layer1.0.conv1.weight                    | (64, 64, 3, 1, 1)
# res2_0_branch2a_bn_s     --> layer1.0.bn1.weight                      | (64,)
# res2_0_branch2a_bn_b     --> layer1.0.bn1.bias                        | (64,)
# res2_0_branch2b_w        --> layer1.0.conv2.weight                    | (64, 64, 1, 3, 3)
# res2_0_branch2b_bn_s     --> layer1.0.bn2.weight                      | (64,)
# res2_0_branch2b_bn_b     --> layer1.0.bn2.bias                        | (64,)
# res2_0_branch2c_w        --> layer1.0.conv3.weight                    | (256, 64, 1, 1, 1)
# res2_0_branch2c_bn_s     --> layer1.0.bn3.weight                      | (256,)
# res2_0_branch2c_bn_b     --> layer1.0.bn3.bias                        | (256,)
# res2_0_branch1_w         --> layer1.0.downsample.0.weight             | (256, 64, 1, 1, 1)
# res2_0_branch1_bn_s      --> layer1.0.downsample.1.weight             | (256,)
# res2_0_branch1_bn_b      --> layer1.0.downsample.1.bias               | (256,)
# res2_1_branch2a_w        --> layer1.1.conv1.weight                    | (64, 256, 3, 1, 1)
# res2_1_branch2a_bn_s     --> layer1.1.bn1.weight                      | (64,)
# res2_1_branch2a_bn_b     --> layer1.1.bn1.bias                        | (64,)
# res2_1_branch2b_w        --> layer1.1.conv2.weight                    | (64, 64, 1, 3, 3)
# res2_1_branch2b_bn_s     --> layer1.1.bn2.weight                      | (64,)
# res2_1_branch2b_bn_b     --> layer1.1.bn2.bias                        | (64,)
# res2_1_branch2c_w        --> layer1.1.conv3.weight                    | (256, 64, 1, 1, 1)
# res2_1_branch2c_bn_s     --> layer1.1.bn3.weight                      | (256,)
# res2_1_branch2c_bn_b     --> layer1.1.bn3.bias                        | (256,)
# res2_2_branch2a_w        --> layer1.2.conv1.weight                    | (64, 256, 3, 1, 1)
# res2_2_branch2a_bn_s     --> layer1.2.bn1.weight                      | (64,)
# res2_2_branch2a_bn_b     --> layer1.2.bn1.bias                        | (64,)
# res2_2_branch2b_w        --> layer1.2.conv2.weight                    | (64, 64, 1, 3, 3)
# res2_2_branch2b_bn_s     --> layer1.2.bn2.weight                      | (64,)
# res2_2_branch2b_bn_b     --> layer1.2.bn2.bias                        | (64,)
# res2_2_branch2c_w        --> layer1.2.conv3.weight                    | (256, 64, 1, 1, 1)
# res2_2_branch2c_bn_s     --> layer1.2.bn3.weight                      | (256,)
# res2_2_branch2c_bn_b     --> layer1.2.bn3.bias                        | (256,)
# res3_0_branch2a_w        --> layer2.0.conv1.weight                    | (128, 256, 3, 1, 1)
# res3_0_branch2a_bn_s     --> layer2.0.bn1.weight                      | (128,)
# res3_0_branch2a_bn_b     --> layer2.0.bn1.bias                        | (128,)
# res3_0_branch2b_w        --> layer2.0.conv2.weight                    | (128, 128, 1, 3, 3)
# res3_0_branch2b_bn_s     --> layer2.0.bn2.weight                      | (128,)
# res3_0_branch2b_bn_b     --> layer2.0.bn2.bias                        | (128,)
# res3_0_branch2c_w        --> layer2.0.conv3.weight                    | (512, 128, 1, 1, 1)
# res3_0_branch2c_bn_s     --> layer2.0.bn3.weight                      | (512,)
# res3_0_branch2c_bn_b     --> layer2.0.bn3.bias                        | (512,)
# res3_0_branch1_w         --> layer2.0.downsample.0.weight             | (512, 256, 1, 1, 1)
# res3_0_branch1_bn_s      --> layer2.0.downsample.1.weight             | (512,)
# res3_0_branch1_bn_b      --> layer2.0.downsample.1.bias               | (512,)
# res3_1_branch2a_w        --> layer2.1.conv1.weight                    | (128, 512, 1, 1, 1)
# res3_1_branch2a_bn_s     --> layer2.1.bn1.weight                      | (128,)
# res3_1_branch2a_bn_b     --> layer2.1.bn1.bias                        | (128,)
# res3_1_branch2b_w        --> layer2.1.conv2.weight                    | (128, 128, 1, 3, 3)
# res3_1_branch2b_bn_s     --> layer2.1.bn2.weight                      | (128,)
# res3_1_branch2b_bn_b     --> layer2.1.bn2.bias                        | (128,)
# res3_1_branch2c_w        --> layer2.1.conv3.weight                    | (512, 128, 1, 1, 1)
# res3_1_branch2c_bn_s     --> layer2.1.bn3.weight                      | (512,)
# res3_1_branch2c_bn_b     --> layer2.1.bn3.bias                        | (512,)
# nonlocal_conv3_1_g_w     --> layer2.1.nonlocal_block.g.1.weight       | (256, 512, 1, 1, 1)
# nonlocal_conv3_1_g_b     --> layer2.1.nonlocal_block.g.1.bias         | (256,)
# nonlocal_conv3_1_out_w   --> layer2.1.nonlocal_block.W.0.weight       | (512, 256, 1, 1, 1)
# nonlocal_conv3_1_out_b   --> layer2.1.nonlocal_block.W.0.bias         | (512,)
# nonlocal_conv3_1_bn_s    --> layer2.1.nonlocal_block.W.1.weight       | (512,)
# nonlocal_conv3_1_bn_b    --> layer2.1.nonlocal_block.W.1.bias         | (512,)
# nonlocal_conv3_1_theta_w --> layer2.1.nonlocal_block.theta.weight     | (256, 512, 1, 1, 1)
# nonlocal_conv3_1_theta_b --> layer2.1.nonlocal_block.theta.bias       | (256,)
# nonlocal_conv3_1_phi_w   --> layer2.1.nonlocal_block.phi.1.weight     | (256, 512, 1, 1, 1)
# nonlocal_conv3_1_phi_b   --> layer2.1.nonlocal_block.phi.1.bias       | (256,)
# res3_2_branch2a_w        --> layer2.2.conv1.weight                    | (128, 512, 3, 1, 1)
# res3_2_branch2a_bn_s     --> layer2.2.bn1.weight                      | (128,)
# res3_2_branch2a_bn_b     --> layer2.2.bn1.bias                        | (128,)
# res3_2_branch2b_w        --> layer2.2.conv2.weight                    | (128, 128, 1, 3, 3)
# res3_2_branch2b_bn_s     --> layer2.2.bn2.weight                      | (128,)
# res3_2_branch2b_bn_b     --> layer2.2.bn2.bias                        | (128,)
# res3_2_branch2c_w        --> layer2.2.conv3.weight                    | (512, 128, 1, 1, 1)
# res3_2_branch2c_bn_s     --> layer2.2.bn3.weight                      | (512,)
# res3_2_branch2c_bn_b     --> layer2.2.bn3.bias                        | (512,)
# res3_3_branch2a_w        --> layer2.3.conv1.weight                    | (128, 512, 1, 1, 1)
# res3_3_branch2a_bn_s     --> layer2.3.bn1.weight                      | (128,)
# res3_3_branch2a_bn_b     --> layer2.3.bn1.bias                        | (128,)
# res3_3_branch2b_w        --> layer2.3.conv2.weight                    | (128, 128, 1, 3, 3)
# res3_3_branch2b_bn_s     --> layer2.3.bn2.weight                      | (128,)
# res3_3_branch2b_bn_b     --> layer2.3.bn2.bias                        | (128,)
# res3_3_branch2c_w        --> layer2.3.conv3.weight                    | (512, 128, 1, 1, 1)
# res3_3_branch2c_bn_s     --> layer2.3.bn3.weight                      | (512,)
# res3_3_branch2c_bn_b     --> layer2.3.bn3.bias                        | (512,)
# nonlocal_conv3_3_g_w     --> layer2.3.nonlocal_block.g.1.weight       | (256, 512, 1, 1, 1)
# nonlocal_conv3_3_g_b     --> layer2.3.nonlocal_block.g.1.bias         | (256,)
# nonlocal_conv3_3_out_w   --> layer2.3.nonlocal_block.W.0.weight       | (512, 256, 1, 1, 1)
# nonlocal_conv3_3_out_b   --> layer2.3.nonlocal_block.W.0.bias         | (512,)
# nonlocal_conv3_3_bn_s    --> layer2.3.nonlocal_block.W.1.weight       | (512,)
# nonlocal_conv3_3_bn_b    --> layer2.3.nonlocal_block.W.1.bias         | (512,)
# nonlocal_conv3_3_theta_w --> layer2.3.nonlocal_block.theta.weight     | (256, 512, 1, 1, 1)
# nonlocal_conv3_3_theta_b --> layer2.3.nonlocal_block.theta.bias       | (256,)
# nonlocal_conv3_3_phi_w   --> layer2.3.nonlocal_block.phi.1.weight     | (256, 512, 1, 1, 1)
# nonlocal_conv3_3_phi_b   --> layer2.3.nonlocal_block.phi.1.bias       | (256,)
# res4_0_branch2a_w        --> layer3.0.conv1.weight                    | (256, 512, 3, 1, 1)
# res4_0_branch2a_bn_s     --> layer3.0.bn1.weight                      | (256,)
# res4_0_branch2a_bn_b     --> layer3.0.bn1.bias                        | (256,)
# res4_0_branch2b_w        --> layer3.0.conv2.weight                    | (256, 256, 1, 3, 3)
# res4_0_branch2b_bn_s     --> layer3.0.bn2.weight                      | (256,)
# res4_0_branch2b_bn_b     --> layer3.0.bn2.bias                        | (256,)
# res4_0_branch2c_w        --> layer3.0.conv3.weight                    | (1024, 256, 1, 1, 1)
# res4_0_branch2c_bn_s     --> layer3.0.bn3.weight                      | (1024,)
# res4_0_branch2c_bn_b     --> layer3.0.bn3.bias                        | (1024,)
# res4_0_branch1_w         --> layer3.0.downsample.0.weight             | (1024, 512, 1, 1, 1)
# res4_0_branch1_bn_s      --> layer3.0.downsample.1.weight             | (1024,)
# res4_0_branch1_bn_b      --> layer3.0.downsample.1.bias               | (1024,)
# res4_1_branch2a_w        --> layer3.1.conv1.weight                    | (256, 1024, 1, 1, 1)
# res4_1_branch2a_bn_s     --> layer3.1.bn1.weight                      | (256,)
# res4_1_branch2a_bn_b     --> layer3.1.bn1.bias                        | (256,)
# res4_1_branch2b_w        --> layer3.1.conv2.weight                    | (256, 256, 1, 3, 3)
# res4_1_branch2b_bn_s     --> layer3.1.bn2.weight                      | (256,)
# res4_1_branch2b_bn_b     --> layer3.1.bn2.bias                        | (256,)
# res4_1_branch2c_w        --> layer3.1.conv3.weight                    | (1024, 256, 1, 1, 1)
# res4_1_branch2c_bn_s     --> layer3.1.bn3.weight                      | (1024,)
# res4_1_branch2c_bn_b     --> layer3.1.bn3.bias                        | (1024,)
# res4_2_branch2a_w        --> layer3.2.conv1.weight                    | (256, 1024, 3, 1, 1)
# res4_2_branch2a_bn_s     --> layer3.2.bn1.weight                      | (256,)
# res4_2_branch2a_bn_b     --> layer3.2.bn1.bias                        | (256,)
# res4_2_branch2b_w        --> layer3.2.conv2.weight                    | (256, 256, 1, 3, 3)
# res4_2_branch2b_bn_s     --> layer3.2.bn2.weight                      | (256,)
# res4_2_branch2b_bn_b     --> layer3.2.bn2.bias                        | (256,)
# res4_2_branch2c_w        --> layer3.2.conv3.weight                    | (1024, 256, 1, 1, 1)
# res4_2_branch2c_bn_s     --> layer3.2.bn3.weight                      | (1024,)
# res4_2_branch2c_bn_b     --> layer3.2.bn3.bias                        | (1024,)
# res4_3_branch2a_w        --> layer3.3.conv1.weight                    | (256, 1024, 1, 1, 1)
# res4_3_branch2a_bn_s     --> layer3.3.bn1.weight                      | (256,)
# res4_3_branch2a_bn_b     --> layer3.3.bn1.bias                        | (256,)
# res4_3_branch2b_w        --> layer3.3.conv2.weight                    | (256, 256, 1, 3, 3)
# res4_3_branch2b_bn_s     --> layer3.3.bn2.weight                      | (256,)
# res4_3_branch2b_bn_b     --> layer3.3.bn2.bias                        | (256,)
# res4_3_branch2c_w        --> layer3.3.conv3.weight                    | (1024, 256, 1, 1, 1)
# res4_3_branch2c_bn_s     --> layer3.3.bn3.weight                      | (1024,)
# res4_3_branch2c_bn_b     --> layer3.3.bn3.bias                        | (1024,)
# res4_4_branch2a_w        --> layer3.4.conv1.weight                    | (256, 1024, 3, 1, 1)
# res4_4_branch2a_bn_s     --> layer3.4.bn1.weight                      | (256,)
# res4_4_branch2a_bn_b     --> layer3.4.bn1.bias                        | (256,)
# res4_4_branch2b_w        --> layer3.4.conv2.weight                    | (256, 256, 1, 3, 3)
# res4_4_branch2b_bn_s     --> layer3.4.bn2.weight                      | (256,)
# res4_4_branch2b_bn_b     --> layer3.4.bn2.bias                        | (256,)
# res4_4_branch2c_w        --> layer3.4.conv3.weight                    | (1024, 256, 1, 1, 1)
# res4_4_branch2c_bn_s     --> layer3.4.bn3.weight                      | (1024,)
# res4_4_branch2c_bn_b     --> layer3.4.bn3.bias                        | (1024,)
# res4_5_branch2a_w        --> layer3.5.conv1.weight                    | (256, 1024, 1, 1, 1)
# res4_5_branch2a_bn_s     --> layer3.5.bn1.weight                      | (256,)
# res4_5_branch2a_bn_b     --> layer3.5.bn1.bias                        | (256,)
# res4_5_branch2b_w        --> layer3.5.conv2.weight                    | (256, 256, 1, 3, 3)
# res4_5_branch2b_bn_s     --> layer3.5.bn2.weight                      | (256,)
# res4_5_branch2b_bn_b     --> layer3.5.bn2.bias                        | (256,)
# res4_5_branch2c_w        --> layer3.5.conv3.weight                    | (1024, 256, 1, 1, 1)
# res4_5_branch2c_bn_s     --> layer3.5.bn3.weight                      | (1024,)
# res4_5_branch2c_bn_b     --> layer3.5.bn3.bias                        | (1024,)
# res4_6_branch2a_w        --> layer3.6.conv1.weight                    | (256, 1024, 3, 1, 1)
# res4_6_branch2a_bn_s     --> layer3.6.bn1.weight                      | (256,)
# res4_6_branch2a_bn_b     --> layer3.6.bn1.bias                        | (256,)
# res4_6_branch2b_w        --> layer3.6.conv2.weight                    | (256, 256, 1, 3, 3)
# res4_6_branch2b_bn_s     --> layer3.6.bn2.weight                      | (256,)
# res4_6_branch2b_bn_b     --> layer3.6.bn2.bias                        | (256,)
# res4_6_branch2c_w        --> layer3.6.conv3.weight                    | (1024, 256, 1, 1, 1)
# res4_6_branch2c_bn_s     --> layer3.6.bn3.weight                      | (1024,)
# res4_6_branch2c_bn_b     --> layer3.6.bn3.bias                        | (1024,)
# nonlocal_conv4_6_g_w     --> layer3.6.nonlocal_block.g.1.weight       | (512, 1024, 1, 1, 1)
# nonlocal_conv4_6_g_b     --> layer3.6.nonlocal_block.g.1.bias         | (512,)
# nonlocal_conv4_6_out_w   --> layer3.6.nonlocal_block.W.0.weight       | (1024, 512, 1, 1, 1)
# nonlocal_conv4_6_out_b   --> layer3.6.nonlocal_block.W.0.bias         | (1024,)
# nonlocal_conv4_6_bn_s    --> layer3.6.nonlocal_block.W.1.weight       | (1024,)
# nonlocal_conv4_6_bn_b    --> layer3.6.nonlocal_block.W.1.bias         | (1024,)
# nonlocal_conv4_6_theta_w --> layer3.6.nonlocal_block.theta.weight     | (512, 1024, 1, 1, 1)
# nonlocal_conv4_6_theta_b --> layer3.6.nonlocal_block.theta.bias       | (512,)
# nonlocal_conv4_6_phi_w   --> layer3.6.nonlocal_block.phi.1.weight     | (512, 1024, 1, 1, 1)
# nonlocal_conv4_6_phi_b   --> layer3.6.nonlocal_block.phi.1.bias       | (512,)
# res4_7_branch2a_w        --> layer3.7.conv1.weight                    | (256, 1024, 1, 1, 1)
# res4_7_branch2a_bn_s     --> layer3.7.bn1.weight                      | (256,)
# res4_7_branch2a_bn_b     --> layer3.7.bn1.bias                        | (256,)
# res4_7_branch2b_w        --> layer3.7.conv2.weight                    | (256, 256, 1, 3, 3)
# res4_7_branch2b_bn_s     --> layer3.7.bn2.weight                      | (256,)
# res4_7_branch2b_bn_b     --> layer3.7.bn2.bias                        | (256,)
# res4_7_branch2c_w        --> layer3.7.conv3.weight                    | (1024, 256, 1, 1, 1)
# res4_7_branch2c_bn_s     --> layer3.7.bn3.weight                      | (1024,)
# res4_7_branch2c_bn_b     --> layer3.7.bn3.bias                        | (1024,)
# res4_8_branch2a_w        --> layer3.8.conv1.weight                    | (256, 1024, 3, 1, 1)
# res4_8_branch2a_bn_s     --> layer3.8.bn1.weight                      | (256,)
# res4_8_branch2a_bn_b     --> layer3.8.bn1.bias                        | (256,)
# res4_8_branch2b_w        --> layer3.8.conv2.weight                    | (256, 256, 1, 3, 3)
# res4_8_branch2b_bn_s     --> layer3.8.bn2.weight                      | (256,)
# res4_8_branch2b_bn_b     --> layer3.8.bn2.bias                        | (256,)
# res4_8_branch2c_w        --> layer3.8.conv3.weight                    | (1024, 256, 1, 1, 1)
# res4_8_branch2c_bn_s     --> layer3.8.bn3.weight                      | (1024,)
# res4_8_branch2c_bn_b     --> layer3.8.bn3.bias                        | (1024,)
# res4_9_branch2a_w        --> layer3.9.conv1.weight                    | (256, 1024, 1, 1, 1)
# res4_9_branch2a_bn_s     --> layer3.9.bn1.weight                      | (256,)
# res4_9_branch2a_bn_b     --> layer3.9.bn1.bias                        | (256,)
# res4_9_branch2b_w        --> layer3.9.conv2.weight                    | (256, 256, 1, 3, 3)
# res4_9_branch2b_bn_s     --> layer3.9.bn2.weight                      | (256,)
# res4_9_branch2b_bn_b     --> layer3.9.bn2.bias                        | (256,)
# res4_9_branch2c_w        --> layer3.9.conv3.weight                    | (1024, 256, 1, 1, 1)
# res4_9_branch2c_bn_s     --> layer3.9.bn3.weight                      | (1024,)
# res4_9_branch2c_bn_b     --> layer3.9.bn3.bias                        | (1024,)
# res5_0_branch2a_w        --> layer4.0.conv1.weight                    | (512, 1024, 1, 1, 1)
# res5_0_branch2a_bn_s     --> layer4.0.bn1.weight                      | (512,)
# res5_0_branch2a_bn_b     --> layer4.0.bn1.bias                        | (512,)
# res5_0_branch2b_w        --> layer4.0.conv2.weight                    | (512, 512, 1, 3, 3)
# res5_0_branch2b_bn_s     --> layer4.0.bn2.weight                      | (512,)
# res5_0_branch2b_bn_b     --> layer4.0.bn2.bias                        | (512,)
# res5_0_branch2c_w        --> layer4.0.conv3.weight                    | (2048, 512, 1, 1, 1)
# res5_0_branch2c_bn_s     --> layer4.0.bn3.weight                      | (2048,)
# res5_0_branch2c_bn_b     --> layer4.0.bn3.bias                        | (2048,)
# res5_0_branch1_w         --> layer4.0.downsample.0.weight             | (2048, 1024, 1, 1, 1)
# res5_0_branch1_bn_s      --> layer4.0.downsample.1.weight             | (2048,)
# res5_0_branch1_bn_b      --> layer4.0.downsample.1.bias               | (2048,)
# res5_1_branch2a_w        --> layer4.1.conv1.weight                    | (512, 2048, 3, 1, 1)
# res5_1_branch2a_bn_s     --> layer4.1.bn1.weight                      | (512,)
# res5_1_branch2a_bn_b     --> layer4.1.bn1.bias                        | (512,)
# res5_1_branch2b_w        --> layer4.1.conv2.weight                    | (512, 512, 1, 3, 3)
# res5_1_branch2b_bn_s     --> layer4.1.bn2.weight                      | (512,)
# res5_1_branch2b_bn_b     --> layer4.1.bn2.bias                        | (512,)
# res5_1_branch2c_w        --> layer4.1.conv3.weight                    | (2048, 512, 1, 1, 1)
# res5_1_branch2c_bn_s     --> layer4.1.bn3.weight                      | (2048,)
# res5_1_branch2c_bn_b     --> layer4.1.bn3.bias                        | (2048,)
# res5_2_branch2a_w        --> layer4.2.conv1.weight                    | (512, 2048, 1, 1, 1)
# res5_2_branch2a_bn_s     --> layer4.2.bn1.weight                      | (512,)
# res5_2_branch2a_bn_b     --> layer4.2.bn1.bias                        | (512,)
# res5_2_branch2b_w        --> layer4.2.conv2.weight                    | (512, 512, 1, 3, 3)
# res5_2_branch2b_bn_s     --> layer4.2.bn2.weight                      | (512,)
# res5_2_branch2b_bn_b     --> layer4.2.bn2.bias                        | (512,)
# res5_2_branch2c_w        --> layer4.2.conv3.weight                    | (2048, 512, 1, 1, 1)
# res5_2_branch2c_bn_s     --> layer4.2.bn3.weight                      | (2048,)
# res5_2_branch2c_bn_b     --> layer4.2.bn3.bias                        | (2048,)
# pred_w                   --> fc.weight                                | (157, 2048)
# pred_b                   --> fc.bias                                  | (157,)

# %%
ava50_i3dnl = convert_i3d_weights(ava50_file, ava_blank_resnet50_i3d, save_model=True,
                                  new_model_name='/data/OnlineActionRecognition/models/pre-trained/'
                                  'long-term-feature-banks/ava_r50_i3d_nl_32x2')
# Out:
# conv1_w                  --> conv1.weight                             | (64, 3, 5, 7, 7)
# res_conv1_bn_s           --> bn1.weight                               | (64,)
# res_conv1_bn_b           --> bn1.bias                                 | (64,)
# res2_0_branch2a_w        --> layer1.0.conv1.weight                    | (64, 64, 3, 1, 1)
# res2_0_branch2a_bn_s     --> layer1.0.bn1.weight                      | (64,)
# res2_0_branch2a_bn_b     --> layer1.0.bn1.bias                        | (64,)
# res2_0_branch2b_w        --> layer1.0.conv2.weight                    | (64, 64, 1, 3, 3)
# res2_0_branch2b_bn_s     --> layer1.0.bn2.weight                      | (64,)
# res2_0_branch2b_bn_b     --> layer1.0.bn2.bias                        | (64,)
# res2_0_branch2c_w        --> layer1.0.conv3.weight                    | (256, 64, 1, 1, 1)
# res2_0_branch2c_bn_s     --> layer1.0.bn3.weight                      | (256,)
# res2_0_branch2c_bn_b     --> layer1.0.bn3.bias                        | (256,)
# res2_0_branch1_w         --> layer1.0.downsample.0.weight             | (256, 64, 1, 1, 1)
# res2_0_branch1_bn_s      --> layer1.0.downsample.1.weight             | (256,)
# res2_0_branch1_bn_b      --> layer1.0.downsample.1.bias               | (256,)
# res2_1_branch2a_w        --> layer1.1.conv1.weight                    | (64, 256, 3, 1, 1)
# res2_1_branch2a_bn_s     --> layer1.1.bn1.weight                      | (64,)
# res2_1_branch2a_bn_b     --> layer1.1.bn1.bias                        | (64,)
# res2_1_branch2b_w        --> layer1.1.conv2.weight                    | (64, 64, 1, 3, 3)
# res2_1_branch2b_bn_s     --> layer1.1.bn2.weight                      | (64,)
# res2_1_branch2b_bn_b     --> layer1.1.bn2.bias                        | (64,)
# res2_1_branch2c_w        --> layer1.1.conv3.weight                    | (256, 64, 1, 1, 1)
# res2_1_branch2c_bn_s     --> layer1.1.bn3.weight                      | (256,)
# res2_1_branch2c_bn_b     --> layer1.1.bn3.bias                        | (256,)
# res2_2_branch2a_w        --> layer1.2.conv1.weight                    | (64, 256, 3, 1, 1)
# res2_2_branch2a_bn_s     --> layer1.2.bn1.weight                      | (64,)
# res2_2_branch2a_bn_b     --> layer1.2.bn1.bias                        | (64,)
# res2_2_branch2b_w        --> layer1.2.conv2.weight                    | (64, 64, 1, 3, 3)
# res2_2_branch2b_bn_s     --> layer1.2.bn2.weight                      | (64,)
# res2_2_branch2b_bn_b     --> layer1.2.bn2.bias                        | (64,)
# res2_2_branch2c_w        --> layer1.2.conv3.weight                    | (256, 64, 1, 1, 1)
# res2_2_branch2c_bn_s     --> layer1.2.bn3.weight                      | (256,)
# res2_2_branch2c_bn_b     --> layer1.2.bn3.bias                        | (256,)
# res3_0_branch2a_w        --> layer2.0.conv1.weight                    | (128, 256, 3, 1, 1)
# res3_0_branch2a_bn_s     --> layer2.0.bn1.weight                      | (128,)
# res3_0_branch2a_bn_b     --> layer2.0.bn1.bias                        | (128,)
# res3_0_branch2b_w        --> layer2.0.conv2.weight                    | (128, 128, 1, 3, 3)
# res3_0_branch2b_bn_s     --> layer2.0.bn2.weight                      | (128,)
# res3_0_branch2b_bn_b     --> layer2.0.bn2.bias                        | (128,)
# res3_0_branch2c_w        --> layer2.0.conv3.weight                    | (512, 128, 1, 1, 1)
# res3_0_branch2c_bn_s     --> layer2.0.bn3.weight                      | (512,)
# res3_0_branch2c_bn_b     --> layer2.0.bn3.bias                        | (512,)
# res3_0_branch1_w         --> layer2.0.downsample.0.weight             | (512, 256, 1, 1, 1)
# res3_0_branch1_bn_s      --> layer2.0.downsample.1.weight             | (512,)
# res3_0_branch1_bn_b      --> layer2.0.downsample.1.bias               | (512,)
# res3_1_branch2a_w        --> layer2.1.conv1.weight                    | (128, 512, 1, 1, 1)
# res3_1_branch2a_bn_s     --> layer2.1.bn1.weight                      | (128,)
# res3_1_branch2a_bn_b     --> layer2.1.bn1.bias                        | (128,)
# res3_1_branch2b_w        --> layer2.1.conv2.weight                    | (128, 128, 1, 3, 3)
# res3_1_branch2b_bn_s     --> layer2.1.bn2.weight                      | (128,)
# res3_1_branch2b_bn_b     --> layer2.1.bn2.bias                        | (128,)
# res3_1_branch2c_w        --> layer2.1.conv3.weight                    | (512, 128, 1, 1, 1)
# res3_1_branch2c_bn_s     --> layer2.1.bn3.weight                      | (512,)
# res3_1_branch2c_bn_b     --> layer2.1.bn3.bias                        | (512,)
# nonlocal_conv3_1_g_w     --> layer2.1.nonlocal_block.g.1.weight       | (256, 512, 1, 1, 1)
# nonlocal_conv3_1_g_b     --> layer2.1.nonlocal_block.g.1.bias         | (256,)
# nonlocal_conv3_1_out_w   --> layer2.1.nonlocal_block.W.0.weight       | (512, 256, 1, 1, 1)
# nonlocal_conv3_1_out_b   --> layer2.1.nonlocal_block.W.0.bias         | (512,)
# nonlocal_conv3_1_bn_s    --> layer2.1.nonlocal_block.W.1.weight       | (512,)
# nonlocal_conv3_1_bn_b    --> layer2.1.nonlocal_block.W.1.bias         | (512,)
# nonlocal_conv3_1_theta_w --> layer2.1.nonlocal_block.theta.weight     | (256, 512, 1, 1, 1)
# nonlocal_conv3_1_theta_b --> layer2.1.nonlocal_block.theta.bias       | (256,)
# nonlocal_conv3_1_phi_w   --> layer2.1.nonlocal_block.phi.1.weight     | (256, 512, 1, 1, 1)
# nonlocal_conv3_1_phi_b   --> layer2.1.nonlocal_block.phi.1.bias       | (256,)
# res3_2_branch2a_w        --> layer2.2.conv1.weight                    | (128, 512, 3, 1, 1)
# res3_2_branch2a_bn_s     --> layer2.2.bn1.weight                      | (128,)
# res3_2_branch2a_bn_b     --> layer2.2.bn1.bias                        | (128,)
# res3_2_branch2b_w        --> layer2.2.conv2.weight                    | (128, 128, 1, 3, 3)
# res3_2_branch2b_bn_s     --> layer2.2.bn2.weight                      | (128,)
# res3_2_branch2b_bn_b     --> layer2.2.bn2.bias                        | (128,)
# res3_2_branch2c_w        --> layer2.2.conv3.weight                    | (512, 128, 1, 1, 1)
# res3_2_branch2c_bn_s     --> layer2.2.bn3.weight                      | (512,)
# res3_2_branch2c_bn_b     --> layer2.2.bn3.bias                        | (512,)
# res3_3_branch2a_w        --> layer2.3.conv1.weight                    | (128, 512, 1, 1, 1)
# res3_3_branch2a_bn_s     --> layer2.3.bn1.weight                      | (128,)
# res3_3_branch2a_bn_b     --> layer2.3.bn1.bias                        | (128,)
# res3_3_branch2b_w        --> layer2.3.conv2.weight                    | (128, 128, 1, 3, 3)
# res3_3_branch2b_bn_s     --> layer2.3.bn2.weight                      | (128,)
# res3_3_branch2b_bn_b     --> layer2.3.bn2.bias                        | (128,)
# res3_3_branch2c_w        --> layer2.3.conv3.weight                    | (512, 128, 1, 1, 1)
# res3_3_branch2c_bn_s     --> layer2.3.bn3.weight                      | (512,)
# res3_3_branch2c_bn_b     --> layer2.3.bn3.bias                        | (512,)
# nonlocal_conv3_3_g_w     --> layer2.3.nonlocal_block.g.1.weight       | (256, 512, 1, 1, 1)
# nonlocal_conv3_3_g_b     --> layer2.3.nonlocal_block.g.1.bias         | (256,)
# nonlocal_conv3_3_out_w   --> layer2.3.nonlocal_block.W.0.weight       | (512, 256, 1, 1, 1)
# nonlocal_conv3_3_out_b   --> layer2.3.nonlocal_block.W.0.bias         | (512,)
# nonlocal_conv3_3_bn_s    --> layer2.3.nonlocal_block.W.1.weight       | (512,)
# nonlocal_conv3_3_bn_b    --> layer2.3.nonlocal_block.W.1.bias         | (512,)
# nonlocal_conv3_3_theta_w --> layer2.3.nonlocal_block.theta.weight     | (256, 512, 1, 1, 1)
# nonlocal_conv3_3_theta_b --> layer2.3.nonlocal_block.theta.bias       | (256,)
# nonlocal_conv3_3_phi_w   --> layer2.3.nonlocal_block.phi.1.weight     | (256, 512, 1, 1, 1)
# nonlocal_conv3_3_phi_b   --> layer2.3.nonlocal_block.phi.1.bias       | (256,)
# res4_0_branch2a_w        --> layer3.0.conv1.weight                    | (256, 512, 3, 1, 1)
# res4_0_branch2a_bn_s     --> layer3.0.bn1.weight                      | (256,)
# res4_0_branch2a_bn_b     --> layer3.0.bn1.bias                        | (256,)
# res4_0_branch2b_w        --> layer3.0.conv2.weight                    | (256, 256, 1, 3, 3)
# res4_0_branch2b_bn_s     --> layer3.0.bn2.weight                      | (256,)
# res4_0_branch2b_bn_b     --> layer3.0.bn2.bias                        | (256,)
# res4_0_branch2c_w        --> layer3.0.conv3.weight                    | (1024, 256, 1, 1, 1)
# res4_0_branch2c_bn_s     --> layer3.0.bn3.weight                      | (1024,)
# res4_0_branch2c_bn_b     --> layer3.0.bn3.bias                        | (1024,)
# res4_0_branch1_w         --> layer3.0.downsample.0.weight             | (1024, 512, 1, 1, 1)
# res4_0_branch1_bn_s      --> layer3.0.downsample.1.weight             | (1024,)
# res4_0_branch1_bn_b      --> layer3.0.downsample.1.bias               | (1024,)
# res4_1_branch2a_w        --> layer3.1.conv1.weight                    | (256, 1024, 1, 1, 1)
# res4_1_branch2a_bn_s     --> layer3.1.bn1.weight                      | (256,)
# res4_1_branch2a_bn_b     --> layer3.1.bn1.bias                        | (256,)
# res4_1_branch2b_w        --> layer3.1.conv2.weight                    | (256, 256, 1, 3, 3)
# res4_1_branch2b_bn_s     --> layer3.1.bn2.weight                      | (256,)
# res4_1_branch2b_bn_b     --> layer3.1.bn2.bias                        | (256,)
# res4_1_branch2c_w        --> layer3.1.conv3.weight                    | (1024, 256, 1, 1, 1)
# res4_1_branch2c_bn_s     --> layer3.1.bn3.weight                      | (1024,)
# res4_1_branch2c_bn_b     --> layer3.1.bn3.bias                        | (1024,)
# nonlocal_conv4_1_g_w     --> layer3.1.nonlocal_block.g.1.weight       | (512, 1024, 1, 1, 1)
# nonlocal_conv4_1_g_b     --> layer3.1.nonlocal_block.g.1.bias         | (512,)
# nonlocal_conv4_1_out_w   --> layer3.1.nonlocal_block.W.0.weight       | (1024, 512, 1, 1, 1)
# nonlocal_conv4_1_out_b   --> layer3.1.nonlocal_block.W.0.bias         | (1024,)
# nonlocal_conv4_1_bn_s    --> layer3.1.nonlocal_block.W.1.weight       | (1024,)
# nonlocal_conv4_1_bn_b    --> layer3.1.nonlocal_block.W.1.bias         | (1024,)
# nonlocal_conv4_1_theta_w --> layer3.1.nonlocal_block.theta.weight     | (512, 1024, 1, 1, 1)
# nonlocal_conv4_1_theta_b --> layer3.1.nonlocal_block.theta.bias       | (512,)
# nonlocal_conv4_1_phi_w   --> layer3.1.nonlocal_block.phi.1.weight     | (512, 1024, 1, 1, 1)
# nonlocal_conv4_1_phi_b   --> layer3.1.nonlocal_block.phi.1.bias       | (512,)
# res4_2_branch2a_w        --> layer3.2.conv1.weight                    | (256, 1024, 3, 1, 1)
# res4_2_branch2a_bn_s     --> layer3.2.bn1.weight                      | (256,)
# res4_2_branch2a_bn_b     --> layer3.2.bn1.bias                        | (256,)
# res4_2_branch2b_w        --> layer3.2.conv2.weight                    | (256, 256, 1, 3, 3)
# res4_2_branch2b_bn_s     --> layer3.2.bn2.weight                      | (256,)
# res4_2_branch2b_bn_b     --> layer3.2.bn2.bias                        | (256,)
# res4_2_branch2c_w        --> layer3.2.conv3.weight                    | (1024, 256, 1, 1, 1)
# res4_2_branch2c_bn_s     --> layer3.2.bn3.weight                      | (1024,)
# res4_2_branch2c_bn_b     --> layer3.2.bn3.bias                        | (1024,)
# res4_3_branch2a_w        --> layer3.3.conv1.weight                    | (256, 1024, 1, 1, 1)
# res4_3_branch2a_bn_s     --> layer3.3.bn1.weight                      | (256,)
# res4_3_branch2a_bn_b     --> layer3.3.bn1.bias                        | (256,)
# res4_3_branch2b_w        --> layer3.3.conv2.weight                    | (256, 256, 1, 3, 3)
# res4_3_branch2b_bn_s     --> layer3.3.bn2.weight                      | (256,)
# res4_3_branch2b_bn_b     --> layer3.3.bn2.bias                        | (256,)
# res4_3_branch2c_w        --> layer3.3.conv3.weight                    | (1024, 256, 1, 1, 1)
# res4_3_branch2c_bn_s     --> layer3.3.bn3.weight                      | (1024,)
# res4_3_branch2c_bn_b     --> layer3.3.bn3.bias                        | (1024,)
# nonlocal_conv4_3_g_w     --> layer3.3.nonlocal_block.g.1.weight       | (512, 1024, 1, 1, 1)
# nonlocal_conv4_3_g_b     --> layer3.3.nonlocal_block.g.1.bias         | (512,)
# nonlocal_conv4_3_out_w   --> layer3.3.nonlocal_block.W.0.weight       | (1024, 512, 1, 1, 1)
# nonlocal_conv4_3_out_b   --> layer3.3.nonlocal_block.W.0.bias         | (1024,)
# nonlocal_conv4_3_bn_s    --> layer3.3.nonlocal_block.W.1.weight       | (1024,)
# nonlocal_conv4_3_bn_b    --> layer3.3.nonlocal_block.W.1.bias         | (1024,)
# nonlocal_conv4_3_theta_w --> layer3.3.nonlocal_block.theta.weight     | (512, 1024, 1, 1, 1)
# nonlocal_conv4_3_theta_b --> layer3.3.nonlocal_block.theta.bias       | (512,)
# nonlocal_conv4_3_phi_w   --> layer3.3.nonlocal_block.phi.1.weight     | (512, 1024, 1, 1, 1)
# nonlocal_conv4_3_phi_b   --> layer3.3.nonlocal_block.phi.1.bias       | (512,)
# res4_4_branch2a_w        --> layer3.4.conv1.weight                    | (256, 1024, 3, 1, 1)
# res4_4_branch2a_bn_s     --> layer3.4.bn1.weight                      | (256,)
# res4_4_branch2a_bn_b     --> layer3.4.bn1.bias                        | (256,)
# res4_4_branch2b_w        --> layer3.4.conv2.weight                    | (256, 256, 1, 3, 3)
# res4_4_branch2b_bn_s     --> layer3.4.bn2.weight                      | (256,)
# res4_4_branch2b_bn_b     --> layer3.4.bn2.bias                        | (256,)
# res4_4_branch2c_w        --> layer3.4.conv3.weight                    | (1024, 256, 1, 1, 1)
# res4_4_branch2c_bn_s     --> layer3.4.bn3.weight                      | (1024,)
# res4_4_branch2c_bn_b     --> layer3.4.bn3.bias                        | (1024,)
# res4_5_branch2a_w        --> layer3.5.conv1.weight                    | (256, 1024, 1, 1, 1)
# res4_5_branch2a_bn_s     --> layer3.5.bn1.weight                      | (256,)
# res4_5_branch2a_bn_b     --> layer3.5.bn1.bias                        | (256,)
# res4_5_branch2b_w        --> layer3.5.conv2.weight                    | (256, 256, 1, 3, 3)
# res4_5_branch2b_bn_s     --> layer3.5.bn2.weight                      | (256,)
# res4_5_branch2b_bn_b     --> layer3.5.bn2.bias                        | (256,)
# res4_5_branch2c_w        --> layer3.5.conv3.weight                    | (1024, 256, 1, 1, 1)
# res4_5_branch2c_bn_s     --> layer3.5.bn3.weight                      | (1024,)
# res4_5_branch2c_bn_b     --> layer3.5.bn3.bias                        | (1024,)
# nonlocal_conv4_5_g_w     --> layer3.5.nonlocal_block.g.1.weight       | (512, 1024, 1, 1, 1)
# nonlocal_conv4_5_g_b     --> layer3.5.nonlocal_block.g.1.bias         | (512,)
# nonlocal_conv4_5_out_w   --> layer3.5.nonlocal_block.W.0.weight       | (1024, 512, 1, 1, 1)
# nonlocal_conv4_5_out_b   --> layer3.5.nonlocal_block.W.0.bias         | (1024,)
# nonlocal_conv4_5_bn_s    --> layer3.5.nonlocal_block.W.1.weight       | (1024,)
# nonlocal_conv4_5_bn_b    --> layer3.5.nonlocal_block.W.1.bias         | (1024,)
# nonlocal_conv4_5_theta_w --> layer3.5.nonlocal_block.theta.weight     | (512, 1024, 1, 1, 1)
# nonlocal_conv4_5_theta_b --> layer3.5.nonlocal_block.theta.bias       | (512,)
# nonlocal_conv4_5_phi_w   --> layer3.5.nonlocal_block.phi.1.weight     | (512, 1024, 1, 1, 1)
# nonlocal_conv4_5_phi_b   --> layer3.5.nonlocal_block.phi.1.bias       | (512,)
# res5_0_branch2a_w        --> layer4.0.conv1.weight                    | (512, 1024, 1, 1, 1)
# res5_0_branch2a_bn_s     --> layer4.0.bn1.weight                      | (512,)
# res5_0_branch2a_bn_b     --> layer4.0.bn1.bias                        | (512,)
# res5_0_branch2b_w        --> layer4.0.conv2.weight                    | (512, 512, 1, 3, 3)
# res5_0_branch2b_bn_s     --> layer4.0.bn2.weight                      | (512,)
# res5_0_branch2b_bn_b     --> layer4.0.bn2.bias                        | (512,)
# res5_0_branch2c_w        --> layer4.0.conv3.weight                    | (2048, 512, 1, 1, 1)
# res5_0_branch2c_bn_s     --> layer4.0.bn3.weight                      | (2048,)
# res5_0_branch2c_bn_b     --> layer4.0.bn3.bias                        | (2048,)
# res5_0_branch1_w         --> layer4.0.downsample.0.weight             | (2048, 1024, 1, 1, 1)
# res5_0_branch1_bn_s      --> layer4.0.downsample.1.weight             | (2048,)
# res5_0_branch1_bn_b      --> layer4.0.downsample.1.bias               | (2048,)
# res5_1_branch2a_w        --> layer4.1.conv1.weight                    | (512, 2048, 3, 1, 1)
# res5_1_branch2a_bn_s     --> layer4.1.bn1.weight                      | (512,)
# res5_1_branch2a_bn_b     --> layer4.1.bn1.bias                        | (512,)
# res5_1_branch2b_w        --> layer4.1.conv2.weight                    | (512, 512, 1, 3, 3)
# res5_1_branch2b_bn_s     --> layer4.1.bn2.weight                      | (512,)
# res5_1_branch2b_bn_b     --> layer4.1.bn2.bias                        | (512,)
# res5_1_branch2c_w        --> layer4.1.conv3.weight                    | (2048, 512, 1, 1, 1)
# res5_1_branch2c_bn_s     --> layer4.1.bn3.weight                      | (2048,)
# res5_1_branch2c_bn_b     --> layer4.1.bn3.bias                        | (2048,)
# res5_2_branch2a_w        --> layer4.2.conv1.weight                    | (512, 2048, 1, 1, 1)
# res5_2_branch2a_bn_s     --> layer4.2.bn1.weight                      | (512,)
# res5_2_branch2a_bn_b     --> layer4.2.bn1.bias                        | (512,)
# res5_2_branch2b_w        --> layer4.2.conv2.weight                    | (512, 512, 1, 3, 3)
# res5_2_branch2b_bn_s     --> layer4.2.bn2.weight                      | (512,)
# res5_2_branch2b_bn_b     --> layer4.2.bn2.bias                        | (512,)
# res5_2_branch2c_w        --> layer4.2.conv3.weight                    | (2048, 512, 1, 1, 1)
# res5_2_branch2c_bn_s     --> layer4.2.bn3.weight                      | (2048,)
# res5_2_branch2c_bn_b     --> layer4.2.bn3.bias                        | (2048,)
# pred_w                   --> fc.weight                                | (80, 2048)
# pred_b                   --> fc.bias                                  | (80,)

# %%
ava101_i3dnl = convert_i3d_weights(ava101_file, ava_blank_resnet101_i3d, save_model=True,
                                   new_model_name='/data/OnlineActionRecognition/models/pre-trained/'
                                   'long-term-feature-banks/ava_r101_i3d_nl_32x2')
# Out:
# conv1_w                  --> conv1.weight                             | (64, 3, 5, 7, 7)
# res_conv1_bn_s           --> bn1.weight                               | (64,)
# res_conv1_bn_b           --> bn1.bias                                 | (64,)
# res2_0_branch2a_w        --> layer1.0.conv1.weight                    | (64, 64, 3, 1, 1)
# res2_0_branch2a_bn_s     --> layer1.0.bn1.weight                      | (64,)
# res2_0_branch2a_bn_b     --> layer1.0.bn1.bias                        | (64,)
# res2_0_branch2b_w        --> layer1.0.conv2.weight                    | (64, 64, 1, 3, 3)
# res2_0_branch2b_bn_s     --> layer1.0.bn2.weight                      | (64,)
# res2_0_branch2b_bn_b     --> layer1.0.bn2.bias                        | (64,)
# res2_0_branch2c_w        --> layer1.0.conv3.weight                    | (256, 64, 1, 1, 1)
# res2_0_branch2c_bn_s     --> layer1.0.bn3.weight                      | (256,)
# res2_0_branch2c_bn_b     --> layer1.0.bn3.bias                        | (256,)
# res2_0_branch1_w         --> layer1.0.downsample.0.weight             | (256, 64, 1, 1, 1)
# res2_0_branch1_bn_s      --> layer1.0.downsample.1.weight             | (256,)
# res2_0_branch1_bn_b      --> layer1.0.downsample.1.bias               | (256,)
# res2_1_branch2a_w        --> layer1.1.conv1.weight                    | (64, 256, 3, 1, 1)
# res2_1_branch2a_bn_s     --> layer1.1.bn1.weight                      | (64,)
# res2_1_branch2a_bn_b     --> layer1.1.bn1.bias                        | (64,)
# res2_1_branch2b_w        --> layer1.1.conv2.weight                    | (64, 64, 1, 3, 3)
# res2_1_branch2b_bn_s     --> layer1.1.bn2.weight                      | (64,)
# res2_1_branch2b_bn_b     --> layer1.1.bn2.bias                        | (64,)
# res2_1_branch2c_w        --> layer1.1.conv3.weight                    | (256, 64, 1, 1, 1)
# res2_1_branch2c_bn_s     --> layer1.1.bn3.weight                      | (256,)
# res2_1_branch2c_bn_b     --> layer1.1.bn3.bias                        | (256,)
# res2_2_branch2a_w        --> layer1.2.conv1.weight                    | (64, 256, 3, 1, 1)
# res2_2_branch2a_bn_s     --> layer1.2.bn1.weight                      | (64,)
# res2_2_branch2a_bn_b     --> layer1.2.bn1.bias                        | (64,)
# res2_2_branch2b_w        --> layer1.2.conv2.weight                    | (64, 64, 1, 3, 3)
# res2_2_branch2b_bn_s     --> layer1.2.bn2.weight                      | (64,)
# res2_2_branch2b_bn_b     --> layer1.2.bn2.bias                        | (64,)
# res2_2_branch2c_w        --> layer1.2.conv3.weight                    | (256, 64, 1, 1, 1)
# res2_2_branch2c_bn_s     --> layer1.2.bn3.weight                      | (256,)
# res2_2_branch2c_bn_b     --> layer1.2.bn3.bias                        | (256,)
# res3_0_branch2a_w        --> layer2.0.conv1.weight                    | (128, 256, 3, 1, 1)
# res3_0_branch2a_bn_s     --> layer2.0.bn1.weight                      | (128,)
# res3_0_branch2a_bn_b     --> layer2.0.bn1.bias                        | (128,)
# res3_0_branch2b_w        --> layer2.0.conv2.weight                    | (128, 128, 1, 3, 3)
# res3_0_branch2b_bn_s     --> layer2.0.bn2.weight                      | (128,)
# res3_0_branch2b_bn_b     --> layer2.0.bn2.bias                        | (128,)
# res3_0_branch2c_w        --> layer2.0.conv3.weight                    | (512, 128, 1, 1, 1)
# res3_0_branch2c_bn_s     --> layer2.0.bn3.weight                      | (512,)
# res3_0_branch2c_bn_b     --> layer2.0.bn3.bias                        | (512,)
# res3_0_branch1_w         --> layer2.0.downsample.0.weight             | (512, 256, 1, 1, 1)
# res3_0_branch1_bn_s      --> layer2.0.downsample.1.weight             | (512,)
# res3_0_branch1_bn_b      --> layer2.0.downsample.1.bias               | (512,)
# res3_1_branch2a_w        --> layer2.1.conv1.weight                    | (128, 512, 1, 1, 1)
# res3_1_branch2a_bn_s     --> layer2.1.bn1.weight                      | (128,)
# res3_1_branch2a_bn_b     --> layer2.1.bn1.bias                        | (128,)
# res3_1_branch2b_w        --> layer2.1.conv2.weight                    | (128, 128, 1, 3, 3)
# res3_1_branch2b_bn_s     --> layer2.1.bn2.weight                      | (128,)
# res3_1_branch2b_bn_b     --> layer2.1.bn2.bias                        | (128,)
# res3_1_branch2c_w        --> layer2.1.conv3.weight                    | (512, 128, 1, 1, 1)
# res3_1_branch2c_bn_s     --> layer2.1.bn3.weight                      | (512,)
# res3_1_branch2c_bn_b     --> layer2.1.bn3.bias                        | (512,)
# nonlocal_conv3_1_g_w     --> layer2.1.nonlocal_block.g.1.weight       | (256, 512, 1, 1, 1)
# nonlocal_conv3_1_g_b     --> layer2.1.nonlocal_block.g.1.bias         | (256,)
# nonlocal_conv3_1_out_w   --> layer2.1.nonlocal_block.W.0.weight       | (512, 256, 1, 1, 1)
# nonlocal_conv3_1_out_b   --> layer2.1.nonlocal_block.W.0.bias         | (512,)
# nonlocal_conv3_1_bn_s    --> layer2.1.nonlocal_block.W.1.weight       | (512,)
# nonlocal_conv3_1_bn_b    --> layer2.1.nonlocal_block.W.1.bias         | (512,)
# nonlocal_conv3_1_theta_w --> layer2.1.nonlocal_block.theta.weight     | (256, 512, 1, 1, 1)
# nonlocal_conv3_1_theta_b --> layer2.1.nonlocal_block.theta.bias       | (256,)
# nonlocal_conv3_1_phi_w   --> layer2.1.nonlocal_block.phi.1.weight     | (256, 512, 1, 1, 1)
# nonlocal_conv3_1_phi_b   --> layer2.1.nonlocal_block.phi.1.bias       | (256,)
# res3_2_branch2a_w        --> layer2.2.conv1.weight                    | (128, 512, 3, 1, 1)
# res3_2_branch2a_bn_s     --> layer2.2.bn1.weight                      | (128,)
# res3_2_branch2a_bn_b     --> layer2.2.bn1.bias                        | (128,)
# res3_2_branch2b_w        --> layer2.2.conv2.weight                    | (128, 128, 1, 3, 3)
# res3_2_branch2b_bn_s     --> layer2.2.bn2.weight                      | (128,)
# res3_2_branch2b_bn_b     --> layer2.2.bn2.bias                        | (128,)
# res3_2_branch2c_w        --> layer2.2.conv3.weight                    | (512, 128, 1, 1, 1)
# res3_2_branch2c_bn_s     --> layer2.2.bn3.weight                      | (512,)
# res3_2_branch2c_bn_b     --> layer2.2.bn3.bias                        | (512,)
# res3_3_branch2a_w        --> layer2.3.conv1.weight                    | (128, 512, 1, 1, 1)
# res3_3_branch2a_bn_s     --> layer2.3.bn1.weight                      | (128,)
# res3_3_branch2a_bn_b     --> layer2.3.bn1.bias                        | (128,)
# res3_3_branch2b_w        --> layer2.3.conv2.weight                    | (128, 128, 1, 3, 3)
# res3_3_branch2b_bn_s     --> layer2.3.bn2.weight                      | (128,)
# res3_3_branch2b_bn_b     --> layer2.3.bn2.bias                        | (128,)
# res3_3_branch2c_w        --> layer2.3.conv3.weight                    | (512, 128, 1, 1, 1)
# res3_3_branch2c_bn_s     --> layer2.3.bn3.weight                      | (512,)
# res3_3_branch2c_bn_b     --> layer2.3.bn3.bias                        | (512,)
# nonlocal_conv3_3_g_w     --> layer2.3.nonlocal_block.g.1.weight       | (256, 512, 1, 1, 1)
# nonlocal_conv3_3_g_b     --> layer2.3.nonlocal_block.g.1.bias         | (256,)
# nonlocal_conv3_3_out_w   --> layer2.3.nonlocal_block.W.0.weight       | (512, 256, 1, 1, 1)
# nonlocal_conv3_3_out_b   --> layer2.3.nonlocal_block.W.0.bias         | (512,)
# nonlocal_conv3_3_bn_s    --> layer2.3.nonlocal_block.W.1.weight       | (512,)
# nonlocal_conv3_3_bn_b    --> layer2.3.nonlocal_block.W.1.bias         | (512,)
# nonlocal_conv3_3_theta_w --> layer2.3.nonlocal_block.theta.weight     | (256, 512, 1, 1, 1)
# nonlocal_conv3_3_theta_b --> layer2.3.nonlocal_block.theta.bias       | (256,)
# nonlocal_conv3_3_phi_w   --> layer2.3.nonlocal_block.phi.1.weight     | (256, 512, 1, 1, 1)
# nonlocal_conv3_3_phi_b   --> layer2.3.nonlocal_block.phi.1.bias       | (256,)
# res4_0_branch2a_w        --> layer3.0.conv1.weight                    | (256, 512, 3, 1, 1)
# res4_0_branch2a_bn_s     --> layer3.0.bn1.weight                      | (256,)
# res4_0_branch2a_bn_b     --> layer3.0.bn1.bias                        | (256,)
# res4_0_branch2b_w        --> layer3.0.conv2.weight                    | (256, 256, 1, 3, 3)
# res4_0_branch2b_bn_s     --> layer3.0.bn2.weight                      | (256,)
# res4_0_branch2b_bn_b     --> layer3.0.bn2.bias                        | (256,)
# res4_0_branch2c_w        --> layer3.0.conv3.weight                    | (1024, 256, 1, 1, 1)
# res4_0_branch2c_bn_s     --> layer3.0.bn3.weight                      | (1024,)
# res4_0_branch2c_bn_b     --> layer3.0.bn3.bias                        | (1024,)
# res4_0_branch1_w         --> layer3.0.downsample.0.weight             | (1024, 512, 1, 1, 1)
# res4_0_branch1_bn_s      --> layer3.0.downsample.1.weight             | (1024,)
# res4_0_branch1_bn_b      --> layer3.0.downsample.1.bias               | (1024,)
# res4_1_branch2a_w        --> layer3.1.conv1.weight                    | (256, 1024, 1, 1, 1)
# res4_1_branch2a_bn_s     --> layer3.1.bn1.weight                      | (256,)
# res4_1_branch2a_bn_b     --> layer3.1.bn1.bias                        | (256,)
# res4_1_branch2b_w        --> layer3.1.conv2.weight                    | (256, 256, 1, 3, 3)
# res4_1_branch2b_bn_s     --> layer3.1.bn2.weight                      | (256,)
# res4_1_branch2b_bn_b     --> layer3.1.bn2.bias                        | (256,)
# res4_1_branch2c_w        --> layer3.1.conv3.weight                    | (1024, 256, 1, 1, 1)
# res4_1_branch2c_bn_s     --> layer3.1.bn3.weight                      | (1024,)
# res4_1_branch2c_bn_b     --> layer3.1.bn3.bias                        | (1024,)
# res4_2_branch2a_w        --> layer3.2.conv1.weight                    | (256, 1024, 3, 1, 1)
# res4_2_branch2a_bn_s     --> layer3.2.bn1.weight                      | (256,)
# res4_2_branch2a_bn_b     --> layer3.2.bn1.bias                        | (256,)
# res4_2_branch2b_w        --> layer3.2.conv2.weight                    | (256, 256, 1, 3, 3)
# res4_2_branch2b_bn_s     --> layer3.2.bn2.weight                      | (256,)
# res4_2_branch2b_bn_b     --> layer3.2.bn2.bias                        | (256,)
# res4_2_branch2c_w        --> layer3.2.conv3.weight                    | (1024, 256, 1, 1, 1)
# res4_2_branch2c_bn_s     --> layer3.2.bn3.weight                      | (1024,)
# res4_2_branch2c_bn_b     --> layer3.2.bn3.bias                        | (1024,)
# res4_3_branch2a_w        --> layer3.3.conv1.weight                    | (256, 1024, 1, 1, 1)
# res4_3_branch2a_bn_s     --> layer3.3.bn1.weight                      | (256,)
# res4_3_branch2a_bn_b     --> layer3.3.bn1.bias                        | (256,)
# res4_3_branch2b_w        --> layer3.3.conv2.weight                    | (256, 256, 1, 3, 3)
# res4_3_branch2b_bn_s     --> layer3.3.bn2.weight                      | (256,)
# res4_3_branch2b_bn_b     --> layer3.3.bn2.bias                        | (256,)
# res4_3_branch2c_w        --> layer3.3.conv3.weight                    | (1024, 256, 1, 1, 1)
# res4_3_branch2c_bn_s     --> layer3.3.bn3.weight                      | (1024,)
# res4_3_branch2c_bn_b     --> layer3.3.bn3.bias                        | (1024,)
# res4_4_branch2a_w        --> layer3.4.conv1.weight                    | (256, 1024, 3, 1, 1)
# res4_4_branch2a_bn_s     --> layer3.4.bn1.weight                      | (256,)
# res4_4_branch2a_bn_b     --> layer3.4.bn1.bias                        | (256,)
# res4_4_branch2b_w        --> layer3.4.conv2.weight                    | (256, 256, 1, 3, 3)
# res4_4_branch2b_bn_s     --> layer3.4.bn2.weight                      | (256,)
# res4_4_branch2b_bn_b     --> layer3.4.bn2.bias                        | (256,)
# res4_4_branch2c_w        --> layer3.4.conv3.weight                    | (1024, 256, 1, 1, 1)
# res4_4_branch2c_bn_s     --> layer3.4.bn3.weight                      | (1024,)
# res4_4_branch2c_bn_b     --> layer3.4.bn3.bias                        | (1024,)
# res4_5_branch2a_w        --> layer3.5.conv1.weight                    | (256, 1024, 1, 1, 1)
# res4_5_branch2a_bn_s     --> layer3.5.bn1.weight                      | (256,)
# res4_5_branch2a_bn_b     --> layer3.5.bn1.bias                        | (256,)
# res4_5_branch2b_w        --> layer3.5.conv2.weight                    | (256, 256, 1, 3, 3)
# res4_5_branch2b_bn_s     --> layer3.5.bn2.weight                      | (256,)
# res4_5_branch2b_bn_b     --> layer3.5.bn2.bias                        | (256,)
# res4_5_branch2c_w        --> layer3.5.conv3.weight                    | (1024, 256, 1, 1, 1)
# res4_5_branch2c_bn_s     --> layer3.5.bn3.weight                      | (1024,)
# res4_5_branch2c_bn_b     --> layer3.5.bn3.bias                        | (1024,)
# res4_6_branch2a_w        --> layer3.6.conv1.weight                    | (256, 1024, 3, 1, 1)
# res4_6_branch2a_bn_s     --> layer3.6.bn1.weight                      | (256,)
# res4_6_branch2a_bn_b     --> layer3.6.bn1.bias                        | (256,)
# res4_6_branch2b_w        --> layer3.6.conv2.weight                    | (256, 256, 1, 3, 3)
# res4_6_branch2b_bn_s     --> layer3.6.bn2.weight                      | (256,)
# res4_6_branch2b_bn_b     --> layer3.6.bn2.bias                        | (256,)
# res4_6_branch2c_w        --> layer3.6.conv3.weight                    | (1024, 256, 1, 1, 1)
# res4_6_branch2c_bn_s     --> layer3.6.bn3.weight                      | (1024,)
# res4_6_branch2c_bn_b     --> layer3.6.bn3.bias                        | (1024,)
# nonlocal_conv4_6_g_w     --> layer3.6.nonlocal_block.g.1.weight       | (512, 1024, 1, 1, 1)
# nonlocal_conv4_6_g_b     --> layer3.6.nonlocal_block.g.1.bias         | (512,)
# nonlocal_conv4_6_out_w   --> layer3.6.nonlocal_block.W.0.weight       | (1024, 512, 1, 1, 1)
# nonlocal_conv4_6_out_b   --> layer3.6.nonlocal_block.W.0.bias         | (1024,)
# nonlocal_conv4_6_bn_s    --> layer3.6.nonlocal_block.W.1.weight       | (1024,)
# nonlocal_conv4_6_bn_b    --> layer3.6.nonlocal_block.W.1.bias         | (1024,)
# nonlocal_conv4_6_theta_w --> layer3.6.nonlocal_block.theta.weight     | (512, 1024, 1, 1, 1)
# nonlocal_conv4_6_theta_b --> layer3.6.nonlocal_block.theta.bias       | (512,)
# nonlocal_conv4_6_phi_w   --> layer3.6.nonlocal_block.phi.1.weight     | (512, 1024, 1, 1, 1)
# nonlocal_conv4_6_phi_b   --> layer3.6.nonlocal_block.phi.1.bias       | (512,)
# res4_7_branch2a_w        --> layer3.7.conv1.weight                    | (256, 1024, 1, 1, 1)
# res4_7_branch2a_bn_s     --> layer3.7.bn1.weight                      | (256,)
# res4_7_branch2a_bn_b     --> layer3.7.bn1.bias                        | (256,)
# res4_7_branch2b_w        --> layer3.7.conv2.weight                    | (256, 256, 1, 3, 3)
# res4_7_branch2b_bn_s     --> layer3.7.bn2.weight                      | (256,)
# res4_7_branch2b_bn_b     --> layer3.7.bn2.bias                        | (256,)
# res4_7_branch2c_w        --> layer3.7.conv3.weight                    | (1024, 256, 1, 1, 1)
# res4_7_branch2c_bn_s     --> layer3.7.bn3.weight                      | (1024,)
# res4_7_branch2c_bn_b     --> layer3.7.bn3.bias                        | (1024,)
# res4_8_branch2a_w        --> layer3.8.conv1.weight                    | (256, 1024, 3, 1, 1)
# res4_8_branch2a_bn_s     --> layer3.8.bn1.weight                      | (256,)
# res4_8_branch2a_bn_b     --> layer3.8.bn1.bias                        | (256,)
# res4_8_branch2b_w        --> layer3.8.conv2.weight                    | (256, 256, 1, 3, 3)
# res4_8_branch2b_bn_s     --> layer3.8.bn2.weight                      | (256,)
# res4_8_branch2b_bn_b     --> layer3.8.bn2.bias                        | (256,)
# res4_8_branch2c_w        --> layer3.8.conv3.weight                    | (1024, 256, 1, 1, 1)
# res4_8_branch2c_bn_s     --> layer3.8.bn3.weight                      | (1024,)
# res4_8_branch2c_bn_b     --> layer3.8.bn3.bias                        | (1024,)
# res4_9_branch2a_w        --> layer3.9.conv1.weight                    | (256, 1024, 1, 1, 1)
# res4_9_branch2a_bn_s     --> layer3.9.bn1.weight                      | (256,)
# res4_9_branch2a_bn_b     --> layer3.9.bn1.bias                        | (256,)
# res4_9_branch2b_w        --> layer3.9.conv2.weight                    | (256, 256, 1, 3, 3)
# res4_9_branch2b_bn_s     --> layer3.9.bn2.weight                      | (256,)
# res4_9_branch2b_bn_b     --> layer3.9.bn2.bias                        | (256,)
# res4_9_branch2c_w        --> layer3.9.conv3.weight                    | (1024, 256, 1, 1, 1)
# res4_9_branch2c_bn_s     --> layer3.9.bn3.weight                      | (1024,)
# res4_9_branch2c_bn_b     --> layer3.9.bn3.bias                        | (1024,)
# res5_0_branch2a_w        --> layer4.0.conv1.weight                    | (512, 1024, 1, 1, 1)
# res5_0_branch2a_bn_s     --> layer4.0.bn1.weight                      | (512,)
# res5_0_branch2a_bn_b     --> layer4.0.bn1.bias                        | (512,)
# res5_0_branch2b_w        --> layer4.0.conv2.weight                    | (512, 512, 1, 3, 3)
# res5_0_branch2b_bn_s     --> layer4.0.bn2.weight                      | (512,)
# res5_0_branch2b_bn_b     --> layer4.0.bn2.bias                        | (512,)
# res5_0_branch2c_w        --> layer4.0.conv3.weight                    | (2048, 512, 1, 1, 1)
# res5_0_branch2c_bn_s     --> layer4.0.bn3.weight                      | (2048,)
# res5_0_branch2c_bn_b     --> layer4.0.bn3.bias                        | (2048,)
# res5_0_branch1_w         --> layer4.0.downsample.0.weight             | (2048, 1024, 1, 1, 1)
# res5_0_branch1_bn_s      --> layer4.0.downsample.1.weight             | (2048,)
# res5_0_branch1_bn_b      --> layer4.0.downsample.1.bias               | (2048,)
# res5_1_branch2a_w        --> layer4.1.conv1.weight                    | (512, 2048, 3, 1, 1)
# res5_1_branch2a_bn_s     --> layer4.1.bn1.weight                      | (512,)
# res5_1_branch2a_bn_b     --> layer4.1.bn1.bias                        | (512,)
# res5_1_branch2b_w        --> layer4.1.conv2.weight                    | (512, 512, 1, 3, 3)
# res5_1_branch2b_bn_s     --> layer4.1.bn2.weight                      | (512,)
# res5_1_branch2b_bn_b     --> layer4.1.bn2.bias                        | (512,)
# res5_1_branch2c_w        --> layer4.1.conv3.weight                    | (2048, 512, 1, 1, 1)
# res5_1_branch2c_bn_s     --> layer4.1.bn3.weight                      | (2048,)
# res5_1_branch2c_bn_b     --> layer4.1.bn3.bias                        | (2048,)
# res5_2_branch2a_w        --> layer4.2.conv1.weight                    | (512, 2048, 1, 1, 1)
# res5_2_branch2a_bn_s     --> layer4.2.bn1.weight                      | (512,)
# res5_2_branch2a_bn_b     --> layer4.2.bn1.bias                        | (512,)
# res5_2_branch2b_w        --> layer4.2.conv2.weight                    | (512, 512, 1, 3, 3)
# res5_2_branch2b_bn_s     --> layer4.2.bn2.weight                      | (512,)
# res5_2_branch2b_bn_b     --> layer4.2.bn2.bias                        | (512,)
# res5_2_branch2c_w        --> layer4.2.conv3.weight                    | (2048, 512, 1, 1, 1)
# res5_2_branch2c_bn_s     --> layer4.2.bn3.weight                      | (2048,)
# res5_2_branch2c_bn_b     --> layer4.2.bn3.bias                        | (2048,)
# pred_w                   --> fc.weight                                | (80, 2048)
# pred_b                   --> fc.bias                                  | (80,)
