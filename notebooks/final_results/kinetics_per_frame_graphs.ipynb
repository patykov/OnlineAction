# %%
import os
import numpy as np

import matplotlib.pyplot as plt

# %%
dir_name = "/Volumes/UBUNTU 18_0/PAKOVA/outputs/Kinetics/"

baseline8_centerCrop_dir = "causal_eval_kinetics_r50_i3d_baseline_8x8_centerCrop"
baseline8_fullyConv_dir = "causal_eval_kinetics_r50_i3d_baseline_8x8_fullyConv"
nl8_centerCrop_dir = "causal_eval_kinetics_r50_i3d_nonlocal_8x8_centerCrop"
nl8_fullyConv_dir = "causal_eval_kinetics_r50_i3d_nonlocal_8x8_fullyConv"

# %%
results_baseline8_centerCrop = np.load(dir_name + baseline8_centerCrop_dir + '_results.npy')
results_baseline8_fullyConv = np.load(dir_name + baseline8_fullyConv_dir + '_results.npy')
results_nl8_centerCrop = np.load(dir_name + nl8_centerCrop_dir + '_results.npy')
results_nl8_fullyConv = np.load(dir_name + nl8_fullyConv_dir + '_results.npy')

# %%
results_baseline8_centerCrop
# Out:
# array([[0.65134888, 0.85057376],
#        [0.71735596, 0.90061986],
#        [0.64277004, 0.8471192 ],
#        [0.65750432, 0.85951631],
#        [0.67254344, 0.87262473],
#        [0.6884971 , 0.88166853],
#        [0.69657555, 0.88969617],
#        [0.70297734, 0.8944213 ],
#        [0.70912509, 0.89848593],
#        [0.7137486 , 0.89980693],
#        [0.71649223, 0.90117874],
#        [0.71923585, 0.90173763]])

# %%
plt.rcParams.update({'font.size': 18})
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]), <a list of 6 Text xticklabel objects>)

# %%
y = np.arange(10, 110, 10)

fig = plt.figure(figsize=(14, 10))
plt.plot(y, results_baseline8_centerCrop[2:, 0], marker='o', color='blue', linewidth=2, label="baseline8_centerCrop")
plt.plot(y, results_baseline8_centerCrop[2:, 1], marker='o', color='blue', linewidth=2, linestyle='dashed')
plt.plot(y, results_baseline8_fullyConv[2:, 0], marker='o', color='purple', linewidth=2, label="baseline8_fullyConv")
plt.plot(y, results_baseline8_fullyConv[2:, 1], marker='o', color='purple', linewidth=2, linestyle='dashed')
plt.plot(y, results_nl8_centerCrop[2:, 0], marker='^', color='green', linewidth=2, label="nonlocal8_centerCrop")
plt.plot(y, results_nl8_centerCrop[2:, 1], marker='^', color='green', linewidth=2, linestyle='dashed')
plt.plot(y, results_nl8_fullyConv[2:, 0], marker='^', color='orange', linewidth=2, label="nonlocal8_fullyConv")
plt.plot(y, results_nl8_fullyConv[2:, 1], marker='^', color='orange', linewidth=2, linestyle='dashed')
plt.legend(loc='lower right', fontsize=18)
plt.xlabel('Percentage of frames seen', fontsize=18)
plt.ylabel('Accuracy', fontsize=18)
fig.savefig('/Volumes/UBUNTU 18_0/PAKOVA/outputs/Kinetics/kinetics_per_frame.pdf')
plt.show()

# %%
y = np.arange(10, 110, 10)

fig = plt.figure(figsize=(12, 7))
plt.plot(y, results_baseline8_centerCrop[2:, 0], marker='o', color='blue', linewidth=2, label="baseline8_centerCrop", linestyle='dashed')
# plt.plot(y, results_baseline8_centerCrop[2:, 1], marker='o', color='blue', linewidth=2, linestyle='dashed')
plt.plot(y, results_baseline8_fullyConv[2:, 0], marker='o', color='purple', linewidth=2, label="baseline8_fullyConv")
# plt.plot(y, results_baseline8_fullyConv[2:, 1], marker='o', color='purple', linewidth=2)
plt.plot(y, results_nl8_centerCrop[2:, 0], marker='^', color='green', linewidth=2, label="nonlocal8_centerCrop", linestyle='dashed')
# plt.plot(y, results_nl8_centerCrop[2:, 1], marker='^', color='green', linewidth=2, linestyle='dashed')
plt.plot(y, results_nl8_fullyConv[2:, 0], marker='^', color='orange', linewidth=2, label="nonlocal8_fullyConv")
# plt.plot(y, results_nl8_fullyConv[2:, 1], marker='^', color='orange', linewidth=2)
plt.legend(loc='lower right', fontsize=14)
plt.xlabel('Percentage of frames seen', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
fig.savefig('/Volumes/UBUNTU 18_0/PAKOVA/outputs/Kinetics/kinetics_per_frame_top1.pdf')
plt.show()

# %%
fig = plt.figure(figsize=(12, 7))
plt.plot(y, results_baseline8_centerCrop[2:, 1], marker='o', color='blue', linewidth=2, label="baseline8_centerCrop", linestyle='dashed')
plt.plot(y, results_baseline8_fullyConv[2:, 1], marker='o', color='purple', linewidth=2, label="baseline8_fullyConv")
plt.plot(y, results_nl8_centerCrop[2:, 1], marker='^', color='green', linewidth=2, label="nonlocal8_centerCrop", linestyle='dashed')
plt.plot(y, results_nl8_fullyConv[2:, 1], marker='^', color='orange', linewidth=2, label="nonlocal8_fullyConv")
plt.legend(loc='lower right', fontsize=14)
plt.xlabel('Percentage of frames seen', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
fig.savefig('/Volumes/UBUNTU 18_0/PAKOVA/outputs/Kinetics/kinetics_per_frame_top5.pdf')
plt.show()

# %%
results_baseline8_centerCrop
# Out:
# array([[0.65134888, 0.85057376],
#        [0.71735596, 0.90061986],
#        [0.64277004, 0.8471192 ],
#        [0.65750432, 0.85951631],
#        [0.67254344, 0.87262473],
#        [0.6884971 , 0.88166853],
#        [0.69657555, 0.88969617],
#        [0.70297734, 0.8944213 ],
#        [0.70912509, 0.89848593],
#        [0.7137486 , 0.89980693],
#        [0.71649223, 0.90117874],
#        [0.71923585, 0.90173763]])

# %%
results_baseline8_fullyConv
# Out:
# array([[0.67416182, 0.8663481 ],
#        [0.73203943, 0.90747891],
#        [0.66421095, 0.85931308],
#        [0.67686211, 0.87257393],
#        [0.6923585 , 0.88354842],
#        [0.70414592, 0.89304949],
#        [0.71166548, 0.89807946],
#        [0.71837212, 0.9015344 ],
#        [0.72482471, 0.90458287],
#        [0.72919419, 0.90717407],
#        [0.73153135, 0.90829184],
#        [0.73341124, 0.90940961]])

# %%
results_nl8_centerCrop
# Out:
# array([[0.66879506, 0.86181267],
#        [0.73468143, 0.90956204],
#        [0.66156895, 0.85850015],
#        [0.67737019, 0.871761  ],
#        [0.68936084, 0.88425973],
#        [0.70252007, 0.89284626],
#        [0.71283406, 0.89873997],
#        [0.71923585, 0.90356671],
#        [0.72431663, 0.9080378 ],
#        [0.72975307, 0.9093588 ],
#        [0.73290316, 0.91067981],
#        [0.73534194, 0.91159435]])

# %%
results_nl8_fullyConv
# Out:
# array([[0.69105737, 0.87622711],
#        [0.74524947, 0.91504928],
#        [0.67955492, 0.86835687],
#        [0.69246012, 0.88171934],
#        [0.70368865, 0.89330353],
#        [0.71659384, 0.90112793],
#        [0.7234529 , 0.90585306],
#        [0.730566  , 0.90991769],
#        [0.7357484 , 0.91245808],
#        [0.74011787, 0.91535413],
#        [0.74331877, 0.91631948],
#        [0.74438573, 0.91723402]])

# %%
a = ((results_baseline8_centerCrop[4] - results_baseline8_centerCrop[2])/results_baseline8_centerCrop[-1])*100
a
# Out:
# array([4.13958745, 2.82848772])

# %%
b = ((results_baseline8_fullyConv[4] - results_baseline8_fullyConv[2])/results_baseline8_fullyConv[-1])*100
b
# Out:
# array([3.83789401, 2.66495335])

# %%
c = ((results_nl8_centerCrop[4] - results_nl8_centerCrop[2])/results_nl8_centerCrop[-1])*100
c
# Out:
# array([3.77945139, 2.82577193])

# %%
d = ((results_nl8_fullyConv[4] - results_nl8_fullyConv[2])/results_nl8_fullyConv[-1])*100
d
# Out:
# array([3.24209952, 2.71976957])

# %%
(a+b+c+d)/4
# Out:
# array([3.74975809, 2.75974564])
